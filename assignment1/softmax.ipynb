# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.334110
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.
#
# **Your answer:**
#
# *We have 10 classes => probability of a correct guess with random choice is 0.1.*
# *Softmax has probabilistic interpretation.*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
print("Gradient check, regularization OFF.")
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
print("Gradient check, regularization ON.")
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# Gradient check, regularization OFF.
# numerical: -1.125962 analytic: -1.125962, relative error: 1.585813e-08
# numerical: 2.652013 analytic: 2.652013, relative error: 1.963607e-08
# numerical: 1.000640 analytic: 1.000640, relative error: 3.685363e-09
# numerical: 1.413166 analytic: 1.413166, relative error: 1.076457e-08
# numerical: 2.396841 analytic: 2.396841, relative error: 1.400467e-08
# numerical: 1.127377 analytic: 1.127377, relative error: 3.796611e-08
# numerical: -1.248517 analytic: -1.248517, relative error: 6.108066e-08
# numerical: 1.043604 analytic: 1.043604, relative error: 1.837273e-08
# numerical: 1.783779 analytic: 1.783779, relative error: 2.804302e-08
# numerical: -1.151502 analytic: -1.151502, relative error: 2.280323e-09
# Gradient check, regularization ON.
# numerical: -0.034835 analytic: -0.034835, relative error: 2.136998e-07
# numerical: 0.252693 analytic: 0.252693, relative error: 2.722542e-08
# numerical: -4.282891 analytic: -4.282891, relative error: 1.126027e-08
# numerical: 0.305627 analytic: 0.305627, relative error: 3.946028e-08
# numerical: 1.248012 analytic: 1.248012, relative error: 7.518194e-09
# numerical: 1.236870 analytic: 1.236870, relative error: 8.807370e-08
# numerical: -0.931685 analytic: -0.931685, relative error: 1.718485e-08
# numerical: 0.056921 analytic: 0.056921, relative error: 1.184044e-07
# numerical: 0.386505 analytic: 0.386505, relative error: 3.778881e-08
# numerical: 2.382003 analytic: 2.382003, relative error: 1.484959e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.334110e+00 computed in 0.199020s
# vectorized loss: 2.334110e+00 computed in 0.009001s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = 10**np.random.uniform(-6.75, -5.25, 10)
regularization_strengths = 10**np.random.uniform(3.25, 4.75, 10)

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
num_iters = 1500
num_combs = len(learning_rates) * len(regularization_strengths)
progress = 1
print("Training:")
for lr in learning_rates:
    for reg in regularization_strengths:
        print("Progress: {}/{} (LR: {:.3e}, reg: {})".format(progress, num_combs, lr, int(reg)))
        # Train
        softmax = Softmax()
        loss_hist = softmax.train(X_train, y_train, learning_rate=lr, reg=reg,
                              num_iters=num_iters, verbose=False)
        # Predict
        y_train_pred = softmax.predict(X_train)
        y_val_pred = softmax.predict(X_val)
        # Evaluate
        acc_train = np.mean(y_train == y_train_pred)
        acc_val = np.mean(y_val == y_val_pred)
        # Best value and softmax
        if acc_val > best_val:
            best_val = acc_val
            best_softmax = softmax
        # Save results
        results[(lr, reg)] = (acc_train, acc_val)
        progress += 1
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# Training:
# Progress: 1/100 (LR: 3.702e-06, reg: 2216)
# Progress: 2/100 (LR: 3.702e-06, reg: 49220)
# Progress: 3/100 (LR: 3.702e-06, reg: 37562)
# Progress: 4/100 (LR: 3.702e-06, reg: 2220)
# Progress: 5/100 (LR: 3.702e-06, reg: 9614)
# Progress: 6/100 (LR: 3.702e-06, reg: 8563)
# Progress: 7/100 (LR: 3.702e-06, reg: 9383)
# Progress: 8/100 (LR: 3.702e-06, reg: 14866)
# Progress: 9/100 (LR: 3.702e-06, reg: 14476)
# Progress: 10/100 (LR: 3.702e-06, reg: 2499)
# Progress: 11/100 (LR: 3.317e-07, reg: 2216)
# Progress: 12/100 (LR: 3.317e-07, reg: 49220)
# Progress: 13/100 (LR: 3.317e-07, reg: 37562)
# Progress: 14/100 (LR: 3.317e-07, reg: 2220)
# Progress: 15/100 (LR: 3.317e-07, reg: 9614)
# Progress: 16/100 (LR: 3.317e-07, reg: 8563)
# Progress: 17/100 (LR: 3.317e-07, reg: 9383)
# Progress: 18/100 (LR: 3.317e-07, reg: 14866)
# Progress: 19/100 (LR: 3.317e-07, reg: 14476)
# Progress: 20/100 (LR: 3.317e-07, reg: 2499)
# Progress: 21/100 (LR: 4.546e-07, reg: 2216)
# Progress: 22/100 (LR: 4.546e-07, reg: 49220)
# Progress: 23/100 (LR: 4.546e-07, reg: 37562)
# Progress: 24/100 (LR: 4.546e-07, reg: 2220)
# Progress: 25/100 (LR: 4.546e-07, reg: 9614)
# Progress: 26/100 (LR: 4.546e-07, reg: 8563)
# Progress: 27/100 (LR: 4.546e-07, reg: 9383)
# Progress: 28/100 (LR: 4.546e-07, reg: 14866)
# Progress: 29/100 (LR: 4.546e-07, reg: 14476)
# Progress: 30/100 (LR: 4.546e-07, reg: 2499)
# Progress: 31/100 (LR: 9.739e-07, reg: 2216)
# Progress: 32/100 (LR: 9.739e-07, reg: 49220)
# Progress: 33/100 (LR: 9.739e-07, reg: 37562)
# Progress: 34/100 (LR: 9.739e-07, reg: 2220)
# Progress: 35/100 (LR: 9.739e-07, reg: 9614)
# Progress: 36/100 (LR: 9.739e-07, reg: 8563)
# Progress: 37/100 (LR: 9.739e-07, reg: 9383)
# Progress: 38/100 (LR: 9.739e-07, reg: 14866)
# Progress: 39/100 (LR: 9.739e-07, reg: 14476)
# Progress: 40/100 (LR: 9.739e-07, reg: 2499)
# Progress: 41/100 (LR: 4.920e-07, reg: 2216)
# Progress: 42/100 (LR: 4.920e-07, reg: 49220)
# Progress: 43/100 (LR: 4.920e-07, reg: 37562)
# Progress: 44/100 (LR: 4.920e-07, reg: 2220)
# Progress: 45/100 (LR: 4.920e-07, reg: 9614)
# Progress: 46/100 (LR: 4.920e-07, reg: 8563)
# Progress: 47/100 (LR: 4.920e-07, reg: 9383)
# Progress: 48/100 (LR: 4.920e-07, reg: 14866)
# Progress: 49/100 (LR: 4.920e-07, reg: 14476)
# Progress: 50/100 (LR: 4.920e-07, reg: 2499)
# Progress: 51/100 (LR: 5.136e-07, reg: 2216)
# Progress: 52/100 (LR: 5.136e-07, reg: 49220)
# Progress: 53/100 (LR: 5.136e-07, reg: 37562)
# Progress: 54/100 (LR: 5.136e-07, reg: 2220)
# Progress: 55/100 (LR: 5.136e-07, reg: 9614)
# Progress: 56/100 (LR: 5.136e-07, reg: 8563)
# Progress: 57/100 (LR: 5.136e-07, reg: 9383)
# Progress: 58/100 (LR: 5.136e-07, reg: 14866)
# Progress: 59/100 (LR: 5.136e-07, reg: 14476)
# Progress: 60/100 (LR: 5.136e-07, reg: 2499)
# Progress: 61/100 (LR: 4.948e-06, reg: 2216)
# Progress: 62/100 (LR: 4.948e-06, reg: 49220)
# Progress: 63/100 (LR: 4.948e-06, reg: 37562)
# Progress: 64/100 (LR: 4.948e-06, reg: 2220)
# Progress: 65/100 (LR: 4.948e-06, reg: 9614)
# Progress: 66/100 (LR: 4.948e-06, reg: 8563)
# Progress: 67/100 (LR: 4.948e-06, reg: 9383)
# Progress: 68/100 (LR: 4.948e-06, reg: 14866)
# Progress: 69/100 (LR: 4.948e-06, reg: 14476)
# Progress: 70/100 (LR: 4.948e-06, reg: 2499)
# Progress: 71/100 (LR: 2.326e-06, reg: 2216)
# Progress: 72/100 (LR: 2.326e-06, reg: 49220)
# Progress: 73/100 (LR: 2.326e-06, reg: 37562)
# Progress: 74/100 (LR: 2.326e-06, reg: 2220)
# Progress: 75/100 (LR: 2.326e-06, reg: 9614)
# Progress: 76/100 (LR: 2.326e-06, reg: 8563)
# Progress: 77/100 (LR: 2.326e-06, reg: 9383)
# Progress: 78/100 (LR: 2.326e-06, reg: 14866)
# Progress: 79/100 (LR: 2.326e-06, reg: 14476)
# Progress: 80/100 (LR: 2.326e-06, reg: 2499)
# Progress: 81/100 (LR: 2.363e-06, reg: 2216)
# Progress: 82/100 (LR: 2.363e-06, reg: 49220)
# Progress: 83/100 (LR: 2.363e-06, reg: 37562)
# Progress: 84/100 (LR: 2.363e-06, reg: 2220)
# Progress: 85/100 (LR: 2.363e-06, reg: 9614)
# Progress: 86/100 (LR: 2.363e-06, reg: 8563)
# Progress: 87/100 (LR: 2.363e-06, reg: 9383)
# Progress: 88/100 (LR: 2.363e-06, reg: 14866)
# Progress: 89/100 (LR: 2.363e-06, reg: 14476)
# Progress: 90/100 (LR: 2.363e-06, reg: 2499)
# Progress: 91/100 (LR: 1.432e-06, reg: 2216)
# Progress: 92/100 (LR: 1.432e-06, reg: 49220)
# Progress: 93/100 (LR: 1.432e-06, reg: 37562)
# Progress: 94/100 (LR: 1.432e-06, reg: 2220)
# Progress: 95/100 (LR: 1.432e-06, reg: 9614)
# Progress: 96/100 (LR: 1.432e-06, reg: 8563)
# Progress: 97/100 (LR: 1.432e-06, reg: 9383)
# Progress: 98/100 (LR: 1.432e-06, reg: 14866)
# Progress: 99/100 (LR: 1.432e-06, reg: 14476)
# Progress: 100/100 (LR: 1.432e-06, reg: 2499)
# lr 3.316520e-07 reg 2.216128e+03 train accuracy: 0.367265 val accuracy: 0.380000
# lr 3.316520e-07 reg 2.220728e+03 train accuracy: 0.366020 val accuracy: 0.386000
# lr 3.316520e-07 reg 2.499250e+03 train accuracy: 0.369531 val accuracy: 0.377000
# lr 3.316520e-07 reg 8.563025e+03 train accuracy: 0.373592 val accuracy: 0.389000
# lr 3.316520e-07 reg 9.383658e+03 train accuracy: 0.373878 val accuracy: 0.381000
# lr 3.316520e-07 reg 9.614205e+03 train accuracy: 0.374673 val accuracy: 0.387000
# lr 3.316520e-07 reg 1.447654e+04 train accuracy: 0.369551 val accuracy: 0.378000
# lr 3.316520e-07 reg 1.486620e+04 train accuracy: 0.360490 val accuracy: 0.368000
# lr 3.316520e-07 reg 3.756222e+04 train accuracy: 0.328796 val accuracy: 0.354000
# lr 3.316520e-07 reg 4.922025e+04 train accuracy: 0.334082 val accuracy: 0.341000
# lr 4.545760e-07 reg 2.216128e+03 train accuracy: 0.382224 val accuracy: 0.379000
# lr 4.545760e-07 reg 2.220728e+03 train accuracy: 0.385633 val accuracy: 0.369000
# lr 4.545760e-07 reg 2.499250e+03 train accuracy: 0.389041 val accuracy: 0.390000
# lr 4.545760e-07 reg 8.563025e+03 train accuracy: 0.379918 val accuracy: 0.393000
# lr 4.545760e-07 reg 9.383658e+03 train accuracy: 0.372857 val accuracy: 0.391000
# lr 4.545760e-07 reg 9.614205e+03 train accuracy: 0.373265 val accuracy: 0.387000
# lr 4.545760e-07 reg 1.447654e+04 train accuracy: 0.366327 val accuracy: 0.379000
# lr 4.545760e-07 reg 1.486620e+04 train accuracy: 0.368041 val accuracy: 0.373000
# lr 4.545760e-07 reg 3.756222e+04 train accuracy: 0.341878 val accuracy: 0.353000
# lr 4.545760e-07 reg 4.922025e+04 train accuracy: 0.329776 val accuracy: 0.354000
# lr 4.920147e-07 reg 2.216128e+03 train accuracy: 0.387143 val accuracy: 0.396000
# lr 4.920147e-07 reg 2.220728e+03 train accuracy: 0.385388 val accuracy: 0.387000
# lr 4.920147e-07 reg 2.499250e+03 train accuracy: 0.391878 val accuracy: 0.389000
# lr 4.920147e-07 reg 8.563025e+03 train accuracy: 0.374735 val accuracy: 0.379000
# lr 4.920147e-07 reg 9.383658e+03 train accuracy: 0.367082 val accuracy: 0.372000
# lr 4.920147e-07 reg 9.614205e+03 train accuracy: 0.373000 val accuracy: 0.392000
# lr 4.920147e-07 reg 1.447654e+04 train accuracy: 0.358429 val accuracy: 0.363000
# lr 4.920147e-07 reg 1.486620e+04 train accuracy: 0.361694 val accuracy: 0.372000
# lr 4.920147e-07 reg 3.756222e+04 train accuracy: 0.330857 val accuracy: 0.338000
# lr 4.920147e-07 reg 4.922025e+04 train accuracy: 0.322776 val accuracy: 0.341000
# lr 5.136286e-07 reg 2.216128e+03 train accuracy: 0.392653 val accuracy: 0.387000
# lr 5.136286e-07 reg 2.220728e+03 train accuracy: 0.389796 val accuracy: 0.380000
# lr 5.136286e-07 reg 2.499250e+03 train accuracy: 0.392163 val accuracy: 0.398000
# lr 5.136286e-07 reg 8.563025e+03 train accuracy: 0.377000 val accuracy: 0.376000
# lr 5.136286e-07 reg 9.383658e+03 train accuracy: 0.370163 val accuracy: 0.387000
# lr 5.136286e-07 reg 9.614205e+03 train accuracy: 0.372143 val accuracy: 0.374000
# lr 5.136286e-07 reg 1.447654e+04 train accuracy: 0.363184 val accuracy: 0.364000
# lr 5.136286e-07 reg 1.486620e+04 train accuracy: 0.365082 val accuracy: 0.370000
# lr 5.136286e-07 reg 3.756222e+04 train accuracy: 0.328653 val accuracy: 0.340000
# lr 5.136286e-07 reg 4.922025e+04 train accuracy: 0.326673 val accuracy: 0.336000
# lr 9.739448e-07 reg 2.216128e+03 train accuracy: 0.401571 val accuracy: 0.403000
# lr 9.739448e-07 reg 2.220728e+03 train accuracy: 0.401265 val accuracy: 0.400000
# lr 9.739448e-07 reg 2.499250e+03 train accuracy: 0.396918 val accuracy: 0.402000
# lr 9.739448e-07 reg 8.563025e+03 train accuracy: 0.375122 val accuracy: 0.382000
# lr 9.739448e-07 reg 9.383658e+03 train accuracy: 0.362918 val accuracy: 0.365000
# lr 9.739448e-07 reg 9.614205e+03 train accuracy: 0.370408 val accuracy: 0.371000
# lr 9.739448e-07 reg 1.447654e+04 train accuracy: 0.359571 val accuracy: 0.375000
# lr 9.739448e-07 reg 1.486620e+04 train accuracy: 0.363980 val accuracy: 0.381000
# lr 9.739448e-07 reg 3.756222e+04 train accuracy: 0.333673 val accuracy: 0.331000
# lr 9.739448e-07 reg 4.922025e+04 train accuracy: 0.323551 val accuracy: 0.333000
# lr 1.431917e-06 reg 2.216128e+03 train accuracy: 0.396224 val accuracy: 0.397000
# lr 1.431917e-06 reg 2.220728e+03 train accuracy: 0.393612 val accuracy: 0.393000
# lr 1.431917e-06 reg 2.499250e+03 train accuracy: 0.398204 val accuracy: 0.411000
# lr 1.431917e-06 reg 8.563025e+03 train accuracy: 0.365571 val accuracy: 0.344000
# lr 1.431917e-06 reg 9.383658e+03 train accuracy: 0.368204 val accuracy: 0.372000
# lr 1.431917e-06 reg 9.614205e+03 train accuracy: 0.367429 val accuracy: 0.385000
# lr 1.431917e-06 reg 1.447654e+04 train accuracy: 0.356837 val accuracy: 0.375000
# lr 1.431917e-06 reg 1.486620e+04 train accuracy: 0.348571 val accuracy: 0.352000
# lr 1.431917e-06 reg 3.756222e+04 train accuracy: 0.328776 val accuracy: 0.346000
# lr 1.431917e-06 reg 4.922025e+04 train accuracy: 0.306673 val accuracy: 0.319000
# lr 2.326450e-06 reg 2.216128e+03 train accuracy: 0.387000 val accuracy: 0.386000
# lr 2.326450e-06 reg 2.220728e+03 train accuracy: 0.391184 val accuracy: 0.387000
# lr 2.326450e-06 reg 2.499250e+03 train accuracy: 0.368143 val accuracy: 0.373000
# lr 2.326450e-06 reg 8.563025e+03 train accuracy: 0.359122 val accuracy: 0.376000
# lr 2.326450e-06 reg 9.383658e+03 train accuracy: 0.345224 val accuracy: 0.343000
# lr 2.326450e-06 reg 9.614205e+03 train accuracy: 0.338327 val accuracy: 0.356000
# lr 2.326450e-06 reg 1.447654e+04 train accuracy: 0.326286 val accuracy: 0.341000
# lr 2.326450e-06 reg 1.486620e+04 train accuracy: 0.343673 val accuracy: 0.344000
# lr 2.326450e-06 reg 3.756222e+04 train accuracy: 0.301306 val accuracy: 0.294000
# lr 2.326450e-06 reg 4.922025e+04 train accuracy: 0.291510 val accuracy: 0.311000
# lr 2.362988e-06 reg 2.216128e+03 train accuracy: 0.381143 val accuracy: 0.386000
# lr 2.362988e-06 reg 2.220728e+03 train accuracy: 0.384000 val accuracy: 0.397000
# lr 2.362988e-06 reg 2.499250e+03 train accuracy: 0.384347 val accuracy: 0.392000
# lr 2.362988e-06 reg 8.563025e+03 train accuracy: 0.364510 val accuracy: 0.354000
# lr 2.362988e-06 reg 9.383658e+03 train accuracy: 0.359510 val accuracy: 0.372000
# lr 2.362988e-06 reg 9.614205e+03 train accuracy: 0.336306 val accuracy: 0.341000
# lr 2.362988e-06 reg 1.447654e+04 train accuracy: 0.327449 val accuracy: 0.328000
# lr 2.362988e-06 reg 1.486620e+04 train accuracy: 0.340796 val accuracy: 0.350000
# lr 2.362988e-06 reg 3.756222e+04 train accuracy: 0.331959 val accuracy: 0.338000
# lr 2.362988e-06 reg 4.922025e+04 train accuracy: 0.288490 val accuracy: 0.303000
# lr 3.702167e-06 reg 2.216128e+03 train accuracy: 0.368347 val accuracy: 0.351000
# lr 3.702167e-06 reg 2.220728e+03 train accuracy: 0.374816 val accuracy: 0.384000
# lr 3.702167e-06 reg 2.499250e+03 train accuracy: 0.356061 val accuracy: 0.354000
# lr 3.702167e-06 reg 8.563025e+03 train accuracy: 0.313612 val accuracy: 0.311000
# lr 3.702167e-06 reg 9.383658e+03 train accuracy: 0.319776 val accuracy: 0.345000
# lr 3.702167e-06 reg 9.614205e+03 train accuracy: 0.333327 val accuracy: 0.343000
# lr 3.702167e-06 reg 1.447654e+04 train accuracy: 0.304776 val accuracy: 0.318000
# lr 3.702167e-06 reg 1.486620e+04 train accuracy: 0.333020 val accuracy: 0.331000
# lr 3.702167e-06 reg 3.756222e+04 train accuracy: 0.283694 val accuracy: 0.288000
# lr 3.702167e-06 reg 4.922025e+04 train accuracy: 0.283143 val accuracy: 0.278000
# lr 4.947779e-06 reg 2.216128e+03 train accuracy: 0.332020 val accuracy: 0.330000
# lr 4.947779e-06 reg 2.220728e+03 train accuracy: 0.343082 val accuracy: 0.325000
# lr 4.947779e-06 reg 2.499250e+03 train accuracy: 0.330163 val accuracy: 0.347000
# lr 4.947779e-06 reg 8.563025e+03 train accuracy: 0.310041 val accuracy: 0.316000
# lr 4.947779e-06 reg 9.383658e+03 train accuracy: 0.291327 val accuracy: 0.292000
# lr 4.947779e-06 reg 9.614205e+03 train accuracy: 0.326592 val accuracy: 0.328000
# lr 4.947779e-06 reg 1.447654e+04 train accuracy: 0.296367 val accuracy: 0.275000
# lr 4.947779e-06 reg 1.486620e+04 train accuracy: 0.289490 val accuracy: 0.289000
# lr 4.947779e-06 reg 3.756222e+04 train accuracy: 0.258449 val accuracy: 0.265000
# lr 4.947779e-06 reg 4.922025e+04 train accuracy: 0.228776 val accuracy: 0.253000
# best validation accuracy achieved during cross-validation: 0.411000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.399000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
