# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.

# %%
# A bit of setup

import numpy as np
import matplotlib.pyplot as plt

from cs231n.classifiers.neural_net import TwoLayerNet

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# We will use the class `TwoLayerNet` in the file `cs231n/classifiers/neural_net.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
    np.random.seed(0)
    return TwoLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
    np.random.seed(1)
    X = 10 * np.random.randn(num_inputs, input_size)
    y = np.array([0, 1, 2, 2, 1])
    return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# # Forward pass: compute scores
# Open the file `cs231n/classifiers/neural_net.py` and look at the method `TwoLayerNet.loss`. This function is very similar to the loss functions you have written for the SVM and Softmax exercises: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.

# %%
scores = net.loss(X)
print('Your scores:')
print(scores)
print()
print('correct scores:')
correct_scores = np.asarray([
  [-0.81233741, -1.27654624, -0.70335995],
  [-0.17129677, -1.18803311, -0.47310444],
  [-0.51590475, -1.01354314, -0.8504215 ],
  [-0.15419291, -0.48629638, -0.52901952],
  [-0.00618733, -0.12435261, -0.15226949]])
print(correct_scores)
print()

# The difference should be very small. We get < 1e-7
print('Difference between your scores and correct scores:')
print(np.sum(np.abs(scores - correct_scores)))
# Out:
# Your scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# correct scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# Difference between your scores and correct scores:
# 3.68027209255e-08

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularizaion loss.

# %%
loss, _ = net.loss(X, y, reg=0.1) # had to change reg to 0.1 to get the correct loss
correct_loss = 1.30378789133

# should be very small, we get < 1e-12
print('Difference between your loss and correct loss:')
print(np.sum(np.abs(loss - correct_loss)))
# Out:
# Difference between your loss and correct loss:
# 1.79856129989e-13

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from cs231n.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, b1, and b2.

loss, grads = net.loss(X, y, reg=0.05)

# these should all be less than 1e-8 or so
for param_name in grads:
    f = lambda W: net.loss(X, y, reg=0.05)[0]
    param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
    print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))
# Out:
# b2 max relative error: 4.447646e-11
# W2 max relative error: 3.440708e-09
# b1 max relative error: 2.738421e-09
# W1 max relative error: 3.561318e-09

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers. Look at the function `TwoLayerNet.train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers. You will also have to implement `TwoLayerNet.predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. You should achieve a training loss less than 0.2.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=5e-6,
            num_iters=100, verbose=False)

print('Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.0171436435329

# %% [markdown]
# # Load the data
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
from cs231n.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    # Reshape data to rows
    X_train = X_train.reshape(num_training, -1)
    X_val = X_val.reshape(num_validation, -1)
    X_test = X_test.reshape(num_test, -1)

    return X_train, y_train, X_val, y_val, X_test, y_test


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (49000, 3072)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3072)
# Test labels shape:  (1000,)

# %% [markdown]
# # Train a network
# To train our network we will use SGD with momentum. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=1000, batch_size=200,
            learning_rate=1e-4, learning_rate_decay=0.95,
            reg=0.25, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
print('Validation accuracy: ', val_acc)
# Out:
# iteration 0 / 1000: loss 2.302762
# iteration 100 / 1000: loss 2.302358
# iteration 200 / 1000: loss 2.297404
# iteration 300 / 1000: loss 2.258897
# iteration 400 / 1000: loss 2.202975
# iteration 500 / 1000: loss 2.116816
# iteration 600 / 1000: loss 2.049789
# iteration 700 / 1000: loss 1.985711
# iteration 800 / 1000: loss 2.003726
# iteration 900 / 1000: loss 1.948076
# Validation accuracy:  0.287

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.29 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
# Fix labels overlaying each other
plt.tight_layout()
plt.show()

# %%
from cs231n.vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
    W1 = net.params['W1']
    W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
    plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
    plt.title('Weights')
    plt.gca().axis('off')
    plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 48% on the validation set. Our best network gets over 52% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can, with a fully-connected Neural Network. For every 1% above 52% on the Test set we will award you with one extra bonus point. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).

# %%
best_net = None # store the best model into this 

#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_net.                                                            #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on the previous exercises.                          #
#################################################################################

# Default values
learn_rates   = [1e-4]
lr_decays     = [0.95]
reg_strengths = [0.25]
hidden_sizes  = [50]

hyperparameters = {'lr'     : learn_rates,
                   'lr_dec' : lr_decays,
                   'reg'    : reg_strengths,
                   'hsize'  : hidden_sizes}

best_val = (-1, 0, hyperparameters)  # Stores a tuple (acc_val, epoch, hyperparams dict)

import itertools

def train_net_iter(input_size, num_classes, num_iters, batch_size, hyperparameters,
                   plot_weights=False):
    """Iterate through hyperparameters and train a network each time.
    
    Return training histories stored in a dictionary with hyperparameters as keys.
    """
    
    results = {}     # Store learning histories here    
    num_combs = np.product([len(hyp) for hyp in hyperparameters.values()])
    progress = 1

    for lr, lr_dec, reg, hsize in itertools.product(*hyperparameters.values()):
        global best_val
        global best_net
        print("Progress: {}/{} (lr: {:.3e}, lr_dec: {:.2f}, reg: {:.3e}, hsize: {})"
              .format(progress, num_combs, lr, lr_dec, reg, int(hsize)))
        # Train
        net = TwoLayerNet(input_size, hsize, num_classes)
        train_hist = net.train(X_train, y_train, X_val, y_val,
                               learning_rate=lr, learning_rate_decay=lr_dec, reg=reg, num_iters=num_iters,
                               batch_size=batch_size, verbose=False)
        # Predict
        acc_val   = (net.predict(X_val) == y_val).mean()
        acc_train = (net.predict(X_train) == y_train).mean()
        print("prediction accuracy - train: {:.3f} | val: {:.3f}".format(acc_train, acc_val))
        # (Optional) Plot weights 
        if plot_weights:
            show_net_weights(net)
        # Choose best network
        if acc_val > best_val[0]:
            best_val = (acc_val, {'lr': lr, 'lr_dec': lr_dec, 'reg': reg, 'hsize': hsize})
            best_net = net
        results[(lr, lr_dec, reg, hsize)] = train_hist        
        progress += 1        
    print("Done training.\n")    
    return results
        
input_size  = 32 * 32 * 3
num_classes = 10
batch_size  = 200
num_epochs  = 7
num_iters   = batch_size * num_epochs

#################################################################################
# Test learning rates
print("Influence of learning rate on loss curve")
print("----------------------------------------")
results = {}
learn_rates = np.power(10, [-4.0, -3.5, -3.0, -2.5])
hyperparameters['lr'] = learn_rates
# train
results = train_net_iter(input_size, num_classes, num_iters, batch_size, hyperparameters)
# plot
plt.subplot(1, 1, 1)
for hyps, train_hist in results.items():
    lr = hyps[0]    
    plt.plot(train_hist['loss_history'], label='log10(lr): {}'.format(np.log10(lr)))
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.legend(loc='best')
plt.show()
print("Faster learning up to 10^-3. 10^-2.5 seems to become unstable and increases noise.\n\n")

#################################################################################
# Test hidden sizes
results = {}
print("Influence of hidden sizes on accuracies")
print("---------------------------------------")
hyperparameters['lr'] = [1e-3]  # Pick some higher learn rate
hidden_sizes  = [50, 100, 150, 200, 500]
hyperparameters['hsize'] = hidden_sizes
# train
results = train_net_iter(input_size, num_classes, num_iters, batch_size, hyperparameters)
# plot
plt.subplot(2, 1, 1)
for hyps, train_hist in results.items():
    hsize = hyps[3]     
    plt.plot(train_hist['loss_history'], label='hsize: {}'.format(hsize))
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.legend(loc='best')
plt.subplot(2, 1, 2)
colors=plt.cm.rainbow(np.linspace(0,1,len(hidden_sizes)))
for color, (hyps, train_hist) in zip(colors, results.items()):
    hsize = hyps[3]    
    plt.plot(train_hist['train_acc_history'], label='hsize: {} (train)'.format(hsize),
             c=color, linestyle='--')
    plt.plot(train_hist['val_acc_history'], label='hsize: {} (val)'.format(hsize),
             c=color, linestyle='-')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()
print("Not much of a difference. Sizes >50 seem to performs better. Larger ones have overfitting. 100 seems to be a good compromise. 500 is the best but might be too huge.\n\n")

#################################################################################
# Try more reg strengths
print("Influence of regularization strength on accuracies")
print("--------------------------------------------------")
results = {}
hyperparameters['lr'] = [10**-3.25]    # Pick some higher learn rate
hyperparameters['hsize'] = [100]  # Pick some higher hidden size
regs = np.power(10, [-4.0, -3.0, -2.0, -1.0, 0.0])
hyperparameters['reg'] = regs
# train
results = train_net_iter(input_size, num_classes, num_iters, batch_size, hyperparameters,
                         plot_weights=True)
# plot
plt.subplot(2, 1, 1)
for hyps, train_hist in results.items():
    reg = hyps[2]
    plt.plot(train_hist['loss_history'], label='reg: {:.3e}'.format(reg))
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.legend(loc='best')
plt.subplot(2, 1, 2)
colors=plt.cm.rainbow(np.linspace(0,1,len(regs)))
for color, (hyps, train_hist) in zip(colors, results.items()):
    reg = hyps[2]
    plt.plot(train_hist['train_acc_history'], label='reg: {:.3e} (train)'.format(reg),
             c=color, linestyle='--')
    plt.plot(train_hist['val_acc_history'], label='reg: {:.3e} (val)'.format(reg),
             c=color, linestyle='-')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.legend(loc='best')
plt.tight_layout()
plt.show()
print("Not much of a difference. Cool images, tho. They seem to provide varied outputs. The original ones had a lot of repeating patterns without much variety.\n\n")

#################################################################################
# Cross plot accuracies vs lr and reg
print("Accuracy at different learning rates and regularization strengths")
print("-----------------------------------------------------------------")
learn_rates = np.power(10, [-4.0, -3.5, -3.0, -2.5])
regs = np.power(10, [-4.0, -3.0, -2.0, -1.0, 0.0])
hyperparameters['lr'] = learn_rates
hyperparameters['reg'] = regs
# train
results = train_net_iter(input_size, num_classes, num_iters, batch_size, hyperparameters,
                         plot_weights=False)
# filter results
subresults = {} # maps (lr, reg) to (acc_train, acc_val)
for hyps, train_hist in results.items():
    lr = hyps[0]
    reg = hyps[2]
    acc_train = train_hist['train_acc_history'][-1] # take last
    acc_val = train_hist['val_acc_history'][-1]
    subresults[(lr, reg)] = (acc_train, acc_val)    
# plot
x_scatter = [np.log10(x[0]) for x in subresults]
y_scatter = [np.log10(x[1]) for x in subresults]
# plot training accuracy
marker_size = 100
colors = [subresults[x][0] for x in subresults]
plt.subplot(2, 1, 1)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 training accuracy')
# plot validation accuracy
colors = [subresults[x][1] for x in subresults] # default size of markers is 20
plt.subplot(2, 1, 2)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 validation accuracy')
# Fix labels overlaying each other
plt.tight_layout()
plt.show()
print("The sweet spot for learning rate seems to be around 10^-3.\n\n")

#################################################################################
# Try learning rate decay
print("Influence of learning rate decay on learning loss and accuracies")
print("----------------------------------------------------------------")
results = {}
learn_rates   = [10**-3.25]
lr_decays     = [0.7]#, 0.8, 0.9, 0.95, 1.0]
reg_strengths = [0.1]
hidden_sizes  = [100]
hyperparameters = {'lr'     : learn_rates,
                   'lr_dec' : lr_decays,
                   'reg'    : reg_strengths,
                   'hsize'  : hidden_sizes}
# train
results = train_net_iter(input_size, num_classes, num_iters, batch_size, hyperparameters,
                         plot_weights=False)
# plot loss function
plt.subplot(2, 1, 1)
for hyps, train_hist in results.items():
    lr_dec = hyps[1]    
    plt.plot(train_hist['loss_history'], label='lr: {:.3f}'.format(lr_dec))
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.legend(loc='upper right')
# plot accuracies
plt.subplot(2, 1, 2)
colors=plt.cm.rainbow(np.linspace(0,1,len(regs)))
for color, (hyps, train_hist) in zip(colors, results.items()):
    lr_dec = hyps[1]
    plt.plot(train_hist['train_acc_history'], label='lr: {:.3f} (train)'.format(lr_dec),
             c=color, linestyle='--')
    plt.plot(train_hist['val_acc_history'], label='lr: {:.3f} (val)'.format(lr_dec),
             c=color, linestyle='-')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()
print("Low learning rates slow down learning and reduce accuracy. High learn rates learn faster but overfit. Optimal seems to be 0.8-0.9.\n\n")

# Print best validation accuracy and epoch
print("Best validation accuracy so far: {} ".format(best_val[0]))
print("Hyperparameters: {}\n".format(best_val[1]))

#################################################################################
# MAXIMUM SEARCH!
# Using random search around most promising hyperparameter areas

print("Searching for hyperparameters randomly in focused ranges (See you the next day!)")
print("--------------------------------------------------------------------------------")

# Ideal values based on previous tests are in the comments
learn_rates   = 10**np.random.uniform(-3.25, -2.75, 8) # 10^-3
lr_decays     = np.random.uniform(0.8, 0.9, 3)         # 0.8-0.9
reg_strengths = 10**np.random.uniform(-0.1, -1.5, 5)   # 0.1
hidden_sizes  = [100, 125, 150]                        # 100-200
hyperparameters = {'lr'     : learn_rates,
                   'lr_dec' : lr_decays,
                   'reg'    : reg_strengths,
                   'hsize'  : hidden_sizes}

# Train
results = train_net_iter(input_size, num_classes, num_iters, batch_size, hyperparameters,
                         plot_weights=False)

print("Best validation accuracy: {} ".format(best_val[0]))
print("Hyperparameters: {}\n".format(best_val[1]))

#################################################################################
#                               END OF YOUR CODE                                #
#################################################################################
# Out:
# Influence of learning rate on loss curve
# ----------------------------------------
# Progress: 1/4 (lr: 1.000e-04, lr_dec: 0.95, reg: 2.500e-01, hsize: 50)
# prediction accuracy - train: 0.326 | val: 0.323
# Progress: 2/4 (lr: 3.162e-04, lr_dec: 0.95, reg: 2.500e-01, hsize: 50)
# prediction accuracy - train: 0.436 | val: 0.443
# Progress: 3/4 (lr: 1.000e-03, lr_dec: 0.95, reg: 2.500e-01, hsize: 50)
# prediction accuracy - train: 0.513 | val: 0.500
# Progress: 4/4 (lr: 3.162e-03, lr_dec: 0.95, reg: 2.500e-01, hsize: 50)
# prediction accuracy - train: 0.479 | val: 0.446
# Done training.
# Faster learning up to 10^-3. 10^-2.5 seems to become unstable and increases noise.
#
#
# Influence of hidden sizes on accuracies
# ---------------------------------------
# Progress: 1/5 (lr: 1.000e-03, lr_dec: 0.95, reg: 2.500e-01, hsize: 50)
# prediction accuracy - train: 0.504 | val: 0.471
# Progress: 2/5 (lr: 1.000e-03, lr_dec: 0.95, reg: 2.500e-01, hsize: 100)
# prediction accuracy - train: 0.528 | val: 0.505
# Progress: 3/5 (lr: 1.000e-03, lr_dec: 0.95, reg: 2.500e-01, hsize: 150)
# prediction accuracy - train: 0.531 | val: 0.512
# Progress: 4/5 (lr: 1.000e-03, lr_dec: 0.95, reg: 2.500e-01, hsize: 200)
# prediction accuracy - train: 0.535 | val: 0.506
# Progress: 5/5 (lr: 1.000e-03, lr_dec: 0.95, reg: 2.500e-01, hsize: 500)
# prediction accuracy - train: 0.551 | val: 0.496
# Done training.
# Not much of a difference. Sizes >50 seem to performs better. Larger ones have overfitting. 100 seems to be a good compromise. 500 is the best but might be too huge.
#
#
# Influence of regularization strength on accuracies
# --------------------------------------------------
# Progress: 1/5 (lr: 5.623e-04, lr_dec: 0.95, reg: 1.000e-04, hsize: 100)
# prediction accuracy - train: 0.497 | val: 0.484
# Progress: 2/5 (lr: 5.623e-04, lr_dec: 0.95, reg: 1.000e-03, hsize: 100)
# prediction accuracy - train: 0.500 | val: 0.485
# Progress: 3/5 (lr: 5.623e-04, lr_dec: 0.95, reg: 1.000e-02, hsize: 100)
# prediction accuracy - train: 0.497 | val: 0.489
# Progress: 4/5 (lr: 5.623e-04, lr_dec: 0.95, reg: 1.000e-01, hsize: 100)
# prediction accuracy - train: 0.494 | val: 0.484
# Progress: 5/5 (lr: 5.623e-04, lr_dec: 0.95, reg: 1.000e+00, hsize: 100)
# prediction accuracy - train: 0.486 | val: 0.475
# Done training.
# Not much of a difference. Cool images, tho. They seem to provide varied outputs. The original ones had a lot of repeating patterns without much variety.
#
#
# Accuracy at different learning rates and regularization strengths
# -----------------------------------------------------------------
# Progress: 1/20 (lr: 1.000e-04, lr_dec: 0.95, reg: 1.000e-04, hsize: 100)
# prediction accuracy - train: 0.336 | val: 0.330
# Progress: 2/20 (lr: 1.000e-04, lr_dec: 0.95, reg: 1.000e-03, hsize: 100)
# prediction accuracy - train: 0.335 | val: 0.332
# Progress: 3/20 (lr: 1.000e-04, lr_dec: 0.95, reg: 1.000e-02, hsize: 100)
# prediction accuracy - train: 0.334 | val: 0.333
# Progress: 4/20 (lr: 1.000e-04, lr_dec: 0.95, reg: 1.000e-01, hsize: 100)
# prediction accuracy - train: 0.336 | val: 0.326
# Progress: 5/20 (lr: 1.000e-04, lr_dec: 0.95, reg: 1.000e+00, hsize: 100)
# prediction accuracy - train: 0.335 | val: 0.331
# Progress: 6/20 (lr: 3.162e-04, lr_dec: 0.95, reg: 1.000e-04, hsize: 100)
# prediction accuracy - train: 0.450 | val: 0.441
# Progress: 7/20 (lr: 3.162e-04, lr_dec: 0.95, reg: 1.000e-03, hsize: 100)
# prediction accuracy - train: 0.450 | val: 0.467
# Progress: 8/20 (lr: 3.162e-04, lr_dec: 0.95, reg: 1.000e-02, hsize: 100)
# prediction accuracy - train: 0.447 | val: 0.447
# Progress: 9/20 (lr: 3.162e-04, lr_dec: 0.95, reg: 1.000e-01, hsize: 100)
# prediction accuracy - train: 0.447 | val: 0.450
# Progress: 10/20 (lr: 3.162e-04, lr_dec: 0.95, reg: 1.000e+00, hsize: 100)
# prediction accuracy - train: 0.441 | val: 0.438
# Progress: 11/20 (lr: 1.000e-03, lr_dec: 0.95, reg: 1.000e-04, hsize: 100)
# prediction accuracy - train: 0.528 | val: 0.492
# Progress: 12/20 (lr: 1.000e-03, lr_dec: 0.95, reg: 1.000e-03, hsize: 100)
# prediction accuracy - train: 0.532 | val: 0.494
# Progress: 13/20 (lr: 1.000e-03, lr_dec: 0.95, reg: 1.000e-02, hsize: 100)
# prediction accuracy - train: 0.524 | val: 0.485
# Progress: 14/20 (lr: 1.000e-03, lr_dec: 0.95, reg: 1.000e-01, hsize: 100)
# prediction accuracy - train: 0.529 | val: 0.509
# Progress: 15/20 (lr: 1.000e-03, lr_dec: 0.95, reg: 1.000e+00, hsize: 100)
# prediction accuracy - train: 0.507 | val: 0.486
# Progress: 16/20 (lr: 3.162e-03, lr_dec: 0.95, reg: 1.000e-04, hsize: 100)
# prediction accuracy - train: 0.530 | val: 0.465
# Progress: 17/20 (lr: 3.162e-03, lr_dec: 0.95, reg: 1.000e-03, hsize: 100)
# prediction accuracy - train: 0.487 | val: 0.459
# Progress: 18/20 (lr: 3.162e-03, lr_dec: 0.95, reg: 1.000e-02, hsize: 100)
# prediction accuracy - train: 0.513 | val: 0.477
# Progress: 19/20 (lr: 3.162e-03, lr_dec: 0.95, reg: 1.000e-01, hsize: 100)
# prediction accuracy - train: 0.477 | val: 0.455
# Progress: 20/20 (lr: 3.162e-03, lr_dec: 0.95, reg: 1.000e+00, hsize: 100)
# prediction accuracy - train: 0.455 | val: 0.450
# Done training.
# The sweet spot for learning rate seems to be around 10^-3.
#
#
# Influence of learning rate decay on learning loss and accuracies
# ----------------------------------------------------------------
# Progress: 1/1 (lr: 5.623e-04, lr_dec: 0.70, reg: 1.000e-01, hsize: 100)
# prediction accuracy - train: 0.421 | val: 0.434
# Done training.
# Low learning rates slow down learning and reduce accuracy. High learn rates learn faster but overfit. Optimal seems to be 0.8-0.9.
#
#
# Best validation accuracy so far: 0.512
# Hyperparameters: {'lr': 0.001, 'lr_dec': 0.95, 'reg': 0.25, 'hsize': 150}
#
# Searching for hyperparameters randomly in focused ranges (See you the next day!)
# --------------------------------------------------------------------------------
# Progress: 1/360 (lr: 7.155e-04, lr_dec: 0.83, reg: 7.263e-01, hsize: 100)
# prediction accuracy - train: 0.476 | val: 0.457
# Progress: 2/360 (lr: 7.155e-04, lr_dec: 0.83, reg: 7.263e-01, hsize: 125)
# prediction accuracy - train: 0.481 | val: 0.456
# Progress: 3/360 (lr: 7.155e-04, lr_dec: 0.83, reg: 7.263e-01, hsize: 150)
# prediction accuracy - train: 0.483 | val: 0.468
# Progress: 4/360 (lr: 7.155e-04, lr_dec: 0.83, reg: 7.098e-01, hsize: 100)
# prediction accuracy - train: 0.478 | val: 0.475
# Progress: 5/360 (lr: 7.155e-04, lr_dec: 0.83, reg: 7.098e-01, hsize: 125)
# prediction accuracy - train: 0.480 | val: 0.456
# Progress: 6/360 (lr: 7.155e-04, lr_dec: 0.83, reg: 7.098e-01, hsize: 150)
# prediction accuracy - train: 0.480 | val: 0.476
# Progress: 7/360 (lr: 7.155e-04, lr_dec: 0.83, reg: 1.166e-01, hsize: 100)
# prediction accuracy - train: 0.485 | val: 0.474
# Progress: 8/360 (lr: 7.155e-04, lr_dec: 0.83, reg: 1.166e-01, hsize: 125)
# prediction accuracy - train: 0.489 | val: 0.468
# Progress: 9/360 (lr: 7.155e-04, lr_dec: 0.83, reg: 1.166e-01, hsize: 150)
# prediction accuracy - train: 0.490 | val: 0.467
# Progress: 10/360 (lr: 7.155e-04, lr_dec: 0.83, reg: 5.846e-02, hsize: 100)
# prediction accuracy - train: 0.486 | val: 0.470
# Progress: 11/360 (lr: 7.155e-04, lr_dec: 0.83, reg: 5.846e-02, hsize: 125)
# prediction accuracy - train: 0.489 | val: 0.473
# Progress: 12/360 (lr: 7.155e-04, lr_dec: 0.83, reg: 5.846e-02, hsize: 150)
# prediction accuracy - train: 0.492 | val: 0.463
# Progress: 13/360 (lr: 7.155e-04, lr_dec: 0.83, reg: 6.300e-02, hsize: 100)
# prediction accuracy - train: 0.486 | val: 0.459
# Progress: 14/360 (lr: 7.155e-04, lr_dec: 0.83, reg: 6.300e-02, hsize: 125)
# prediction accuracy - train: 0.491 | val: 0.477
# Progress: 15/360 (lr: 7.155e-04, lr_dec: 0.83, reg: 6.300e-02, hsize: 150)
# prediction accuracy - train: 0.489 | val: 0.483
# Progress: 16/360 (lr: 7.155e-04, lr_dec: 0.89, reg: 7.263e-01, hsize: 100)
# prediction accuracy - train: 0.489 | val: 0.474
# Progress: 17/360 (lr: 7.155e-04, lr_dec: 0.89, reg: 7.263e-01, hsize: 125)
# prediction accuracy - train: 0.488 | val: 0.460
# Progress: 18/360 (lr: 7.155e-04, lr_dec: 0.89, reg: 7.263e-01, hsize: 150)
# prediction accuracy - train: 0.496 | val: 0.471
# Progress: 19/360 (lr: 7.155e-04, lr_dec: 0.89, reg: 7.098e-01, hsize: 100)
# prediction accuracy - train: 0.490 | val: 0.471
# Progress: 20/360 (lr: 7.155e-04, lr_dec: 0.89, reg: 7.098e-01, hsize: 125)
# prediction accuracy - train: 0.491 | val: 0.467
# Progress: 21/360 (lr: 7.155e-04, lr_dec: 0.89, reg: 7.098e-01, hsize: 150)
# prediction accuracy - train: 0.498 | val: 0.480
# Progress: 22/360 (lr: 7.155e-04, lr_dec: 0.89, reg: 1.166e-01, hsize: 100)
# prediction accuracy - train: 0.500 | val: 0.479
# Progress: 23/360 (lr: 7.155e-04, lr_dec: 0.89, reg: 1.166e-01, hsize: 125)
# prediction accuracy - train: 0.497 | val: 0.477
# Progress: 24/360 (lr: 7.155e-04, lr_dec: 0.89, reg: 1.166e-01, hsize: 150)
# prediction accuracy - train: 0.504 | val: 0.477
# Progress: 25/360 (lr: 7.155e-04, lr_dec: 0.89, reg: 5.846e-02, hsize: 100)
# prediction accuracy - train: 0.503 | val: 0.465
# Progress: 26/360 (lr: 7.155e-04, lr_dec: 0.89, reg: 5.846e-02, hsize: 125)
# prediction accuracy - train: 0.504 | val: 0.485
# Progress: 27/360 (lr: 7.155e-04, lr_dec: 0.89, reg: 5.846e-02, hsize: 150)
# prediction accuracy - train: 0.505 | val: 0.467
# Progress: 28/360 (lr: 7.155e-04, lr_dec: 0.89, reg: 6.300e-02, hsize: 100)
# prediction accuracy - train: 0.501 | val: 0.483
# Progress: 29/360 (lr: 7.155e-04, lr_dec: 0.89, reg: 6.300e-02, hsize: 125)
# prediction accuracy - train: 0.506 | val: 0.487
# Progress: 30/360 (lr: 7.155e-04, lr_dec: 0.89, reg: 6.300e-02, hsize: 150)
# prediction accuracy - train: 0.508 | val: 0.495
# Progress: 31/360 (lr: 7.155e-04, lr_dec: 0.83, reg: 7.263e-01, hsize: 100)
# prediction accuracy - train: 0.478 | val: 0.473
# Progress: 32/360 (lr: 7.155e-04, lr_dec: 0.83, reg: 7.263e-01, hsize: 125)
# prediction accuracy - train: 0.481 | val: 0.472
# Progress: 33/360 (lr: 7.155e-04, lr_dec: 0.83, reg: 7.263e-01, hsize: 150)
# prediction accuracy - train: 0.480 | val: 0.467
# Progress: 34/360 (lr: 7.155e-04, lr_dec: 0.83, reg: 7.098e-01, hsize: 100)
# prediction accuracy - train: 0.476 | val: 0.480
# Progress: 35/360 (lr: 7.155e-04, lr_dec: 0.83, reg: 7.098e-01, hsize: 125)
# prediction accuracy - train: 0.479 | val: 0.462
# Progress: 36/360 (lr: 7.155e-04, lr_dec: 0.83, reg: 7.098e-01, hsize: 150)
# prediction accuracy - train: 0.482 | val: 0.466
# Progress: 37/360 (lr: 7.155e-04, lr_dec: 0.83, reg: 1.166e-01, hsize: 100)
# prediction accuracy - train: 0.488 | val: 0.470
# Progress: 38/360 (lr: 7.155e-04, lr_dec: 0.83, reg: 1.166e-01, hsize: 125)
# prediction accuracy - train: 0.490 | val: 0.458
# Progress: 39/360 (lr: 7.155e-04, lr_dec: 0.83, reg: 1.166e-01, hsize: 150)
# prediction accuracy - train: 0.493 | val: 0.477
# Progress: 40/360 (lr: 7.155e-04, lr_dec: 0.83, reg: 5.846e-02, hsize: 100)
# prediction accuracy - train: 0.485 | val: 0.471
# Progress: 41/360 (lr: 7.155e-04, lr_dec: 0.83, reg: 5.846e-02, hsize: 125)
# prediction accuracy - train: 0.491 | val: 0.471
# Progress: 42/360 (lr: 7.155e-04, lr_dec: 0.83, reg: 5.846e-02, hsize: 150)
# prediction accuracy - train: 0.490 | val: 0.468
# Progress: 43/360 (lr: 7.155e-04, lr_dec: 0.83, reg: 6.300e-02, hsize: 100)
# prediction accuracy - train: 0.486 | val: 0.472
# Progress: 44/360 (lr: 7.155e-04, lr_dec: 0.83, reg: 6.300e-02, hsize: 125)
# prediction accuracy - train: 0.491 | val: 0.482
# Progress: 45/360 (lr: 7.155e-04, lr_dec: 0.83, reg: 6.300e-02, hsize: 150)
# prediction accuracy - train: 0.491 | val: 0.479
# Progress: 46/360 (lr: 1.409e-03, lr_dec: 0.83, reg: 7.263e-01, hsize: 100)
# prediction accuracy - train: 0.524 | val: 0.494
# Progress: 47/360 (lr: 1.409e-03, lr_dec: 0.83, reg: 7.263e-01, hsize: 125)
# prediction accuracy - train: 0.528 | val: 0.494
# Progress: 48/360 (lr: 1.409e-03, lr_dec: 0.83, reg: 7.263e-01, hsize: 150)
# prediction accuracy - train: 0.520 | val: 0.493
# Progress: 49/360 (lr: 1.409e-03, lr_dec: 0.83, reg: 7.098e-01, hsize: 100)
# prediction accuracy - train: 0.516 | val: 0.490
# Progress: 50/360 (lr: 1.409e-03, lr_dec: 0.83, reg: 7.098e-01, hsize: 125)
# prediction accuracy - train: 0.525 | val: 0.494
# Progress: 51/360 (lr: 1.409e-03, lr_dec: 0.83, reg: 7.098e-01, hsize: 150)
# prediction accuracy - train: 0.529 | val: 0.482
# Progress: 52/360 (lr: 1.409e-03, lr_dec: 0.83, reg: 1.166e-01, hsize: 100)
# prediction accuracy - train: 0.542 | val: 0.497
# Progress: 53/360 (lr: 1.409e-03, lr_dec: 0.83, reg: 1.166e-01, hsize: 125)
# prediction accuracy - train: 0.537 | val: 0.516
# Progress: 54/360 (lr: 1.409e-03, lr_dec: 0.83, reg: 1.166e-01, hsize: 150)
# prediction accuracy - train: 0.547 | val: 0.520
# Progress: 55/360 (lr: 1.409e-03, lr_dec: 0.83, reg: 5.846e-02, hsize: 100)
# prediction accuracy - train: 0.537 | val: 0.494
# Progress: 56/360 (lr: 1.409e-03, lr_dec: 0.83, reg: 5.846e-02, hsize: 125)
# prediction accuracy - train: 0.542 | val: 0.507
# Progress: 57/360 (lr: 1.409e-03, lr_dec: 0.83, reg: 5.846e-02, hsize: 150)
# prediction accuracy - train: 0.546 | val: 0.503
# Progress: 58/360 (lr: 1.409e-03, lr_dec: 0.83, reg: 6.300e-02, hsize: 100)
# prediction accuracy - train: 0.538 | val: 0.494
# Progress: 59/360 (lr: 1.409e-03, lr_dec: 0.83, reg: 6.300e-02, hsize: 125)
# prediction accuracy - train: 0.540 | val: 0.509
# Progress: 60/360 (lr: 1.409e-03, lr_dec: 0.83, reg: 6.300e-02, hsize: 150)
# prediction accuracy - train: 0.541 | val: 0.510
# Progress: 61/360 (lr: 1.409e-03, lr_dec: 0.89, reg: 7.263e-01, hsize: 100)
# prediction accuracy - train: 0.516 | val: 0.492
# Progress: 62/360 (lr: 1.409e-03, lr_dec: 0.89, reg: 7.263e-01, hsize: 125)
# prediction accuracy - train: 0.531 | val: 0.486
# Progress: 63/360 (lr: 1.409e-03, lr_dec: 0.89, reg: 7.263e-01, hsize: 150)
# prediction accuracy - train: 0.528 | val: 0.491
# Progress: 64/360 (lr: 1.409e-03, lr_dec: 0.89, reg: 7.098e-01, hsize: 100)
# prediction accuracy - train: 0.523 | val: 0.484
# Progress: 65/360 (lr: 1.409e-03, lr_dec: 0.89, reg: 7.098e-01, hsize: 125)
# prediction accuracy - train: 0.522 | val: 0.496
# Progress: 66/360 (lr: 1.409e-03, lr_dec: 0.89, reg: 7.098e-01, hsize: 150)
# prediction accuracy - train: 0.528 | val: 0.506
# Progress: 67/360 (lr: 1.409e-03, lr_dec: 0.89, reg: 1.166e-01, hsize: 100)
# prediction accuracy - train: 0.545 | val: 0.512
# Progress: 68/360 (lr: 1.409e-03, lr_dec: 0.89, reg: 1.166e-01, hsize: 125)
# prediction accuracy - train: 0.551 | val: 0.517
# Progress: 69/360 (lr: 1.409e-03, lr_dec: 0.89, reg: 1.166e-01, hsize: 150)
# prediction accuracy - train: 0.552 | val: 0.522
# Progress: 70/360 (lr: 1.409e-03, lr_dec: 0.89, reg: 5.846e-02, hsize: 100)
# prediction accuracy - train: 0.546 | val: 0.497
# Progress: 71/360 (lr: 1.409e-03, lr_dec: 0.89, reg: 5.846e-02, hsize: 125)
# prediction accuracy - train: 0.547 | val: 0.506
# Progress: 72/360 (lr: 1.409e-03, lr_dec: 0.89, reg: 5.846e-02, hsize: 150)
# prediction accuracy - train: 0.553 | val: 0.509
# Progress: 73/360 (lr: 1.409e-03, lr_dec: 0.89, reg: 6.300e-02, hsize: 100)
# prediction accuracy - train: 0.541 | val: 0.499
# Progress: 74/360 (lr: 1.409e-03, lr_dec: 0.89, reg: 6.300e-02, hsize: 125)
# prediction accuracy - train: 0.554 | val: 0.528
# Progress: 75/360 (lr: 1.409e-03, lr_dec: 0.89, reg: 6.300e-02, hsize: 150)
# prediction accuracy - train: 0.546 | val: 0.510
# Progress: 76/360 (lr: 1.409e-03, lr_dec: 0.83, reg: 7.263e-01, hsize: 100)
# prediction accuracy - train: 0.520 | val: 0.491
# Progress: 77/360 (lr: 1.409e-03, lr_dec: 0.83, reg: 7.263e-01, hsize: 125)
# prediction accuracy - train: 0.527 | val: 0.493
# Progress: 78/360 (lr: 1.409e-03, lr_dec: 0.83, reg: 7.263e-01, hsize: 150)
# prediction accuracy - train: 0.523 | val: 0.474
# Progress: 79/360 (lr: 1.409e-03, lr_dec: 0.83, reg: 7.098e-01, hsize: 100)
# prediction accuracy - train: 0.520 | val: 0.494
# Progress: 80/360 (lr: 1.409e-03, lr_dec: 0.83, reg: 7.098e-01, hsize: 125)
# prediction accuracy - train: 0.524 | val: 0.487
# Progress: 81/360 (lr: 1.409e-03, lr_dec: 0.83, reg: 7.098e-01, hsize: 150)
# prediction accuracy - train: 0.529 | val: 0.497
# Progress: 82/360 (lr: 1.409e-03, lr_dec: 0.83, reg: 1.166e-01, hsize: 100)
# prediction accuracy - train: 0.532 | val: 0.490
# Progress: 83/360 (lr: 1.409e-03, lr_dec: 0.83, reg: 1.166e-01, hsize: 125)
# prediction accuracy - train: 0.539 | val: 0.518
# Progress: 84/360 (lr: 1.409e-03, lr_dec: 0.83, reg: 1.166e-01, hsize: 150)
# prediction accuracy - train: 0.544 | val: 0.503
# Progress: 85/360 (lr: 1.409e-03, lr_dec: 0.83, reg: 5.846e-02, hsize: 100)
# prediction accuracy - train: 0.541 | val: 0.494
# Progress: 86/360 (lr: 1.409e-03, lr_dec: 0.83, reg: 5.846e-02, hsize: 125)
# prediction accuracy - train: 0.538 | val: 0.508
# Progress: 87/360 (lr: 1.409e-03, lr_dec: 0.83, reg: 5.846e-02, hsize: 150)
# prediction accuracy - train: 0.546 | val: 0.514
# Progress: 88/360 (lr: 1.409e-03, lr_dec: 0.83, reg: 6.300e-02, hsize: 100)
# prediction accuracy - train: 0.527 | val: 0.494
# Progress: 89/360 (lr: 1.409e-03, lr_dec: 0.83, reg: 6.300e-02, hsize: 125)
# prediction accuracy - train: 0.538 | val: 0.492
# Progress: 90/360 (lr: 1.409e-03, lr_dec: 0.83, reg: 6.300e-02, hsize: 150)
# prediction accuracy - train: 0.543 | val: 0.508
# Progress: 91/360 (lr: 7.129e-04, lr_dec: 0.83, reg: 7.263e-01, hsize: 100)
# prediction accuracy - train: 0.478 | val: 0.467
# Progress: 92/360 (lr: 7.129e-04, lr_dec: 0.83, reg: 7.263e-01, hsize: 125)
# prediction accuracy - train: 0.479 | val: 0.464
# Progress: 93/360 (lr: 7.129e-04, lr_dec: 0.83, reg: 7.263e-01, hsize: 150)
# prediction accuracy - train: 0.481 | val: 0.463
# Progress: 94/360 (lr: 7.129e-04, lr_dec: 0.83, reg: 7.098e-01, hsize: 100)
# prediction accuracy - train: 0.478 | val: 0.475
# Progress: 95/360 (lr: 7.129e-04, lr_dec: 0.83, reg: 7.098e-01, hsize: 125)
# prediction accuracy - train: 0.482 | val: 0.474
# Progress: 96/360 (lr: 7.129e-04, lr_dec: 0.83, reg: 7.098e-01, hsize: 150)
# prediction accuracy - train: 0.483 | val: 0.472
# Progress: 97/360 (lr: 7.129e-04, lr_dec: 0.83, reg: 1.166e-01, hsize: 100)
# prediction accuracy - train: 0.485 | val: 0.475
# Progress: 98/360 (lr: 7.129e-04, lr_dec: 0.83, reg: 1.166e-01, hsize: 125)
# prediction accuracy - train: 0.491 | val: 0.480
# Progress: 99/360 (lr: 7.129e-04, lr_dec: 0.83, reg: 1.166e-01, hsize: 150)
# prediction accuracy - train: 0.489 | val: 0.480
# Progress: 100/360 (lr: 7.129e-04, lr_dec: 0.83, reg: 5.846e-02, hsize: 100)
# prediction accuracy - train: 0.488 | val: 0.464
# Progress: 101/360 (lr: 7.129e-04, lr_dec: 0.83, reg: 5.846e-02, hsize: 125)
# prediction accuracy - train: 0.487 | val: 0.473
# Progress: 102/360 (lr: 7.129e-04, lr_dec: 0.83, reg: 5.846e-02, hsize: 150)
# prediction accuracy - train: 0.490 | val: 0.467
# Progress: 103/360 (lr: 7.129e-04, lr_dec: 0.83, reg: 6.300e-02, hsize: 100)
# prediction accuracy - train: 0.485 | val: 0.466
# Progress: 104/360 (lr: 7.129e-04, lr_dec: 0.83, reg: 6.300e-02, hsize: 125)
# prediction accuracy - train: 0.486 | val: 0.472
# Progress: 105/360 (lr: 7.129e-04, lr_dec: 0.83, reg: 6.300e-02, hsize: 150)
# prediction accuracy - train: 0.490 | val: 0.469
# Progress: 106/360 (lr: 7.129e-04, lr_dec: 0.89, reg: 7.263e-01, hsize: 100)
# prediction accuracy - train: 0.491 | val: 0.472
# Progress: 107/360 (lr: 7.129e-04, lr_dec: 0.89, reg: 7.263e-01, hsize: 125)
# prediction accuracy - train: 0.492 | val: 0.475
# Progress: 108/360 (lr: 7.129e-04, lr_dec: 0.89, reg: 7.263e-01, hsize: 150)
# prediction accuracy - train: 0.497 | val: 0.459
# Progress: 109/360 (lr: 7.129e-04, lr_dec: 0.89, reg: 7.098e-01, hsize: 100)
# prediction accuracy - train: 0.493 | val: 0.465
# Progress: 110/360 (lr: 7.129e-04, lr_dec: 0.89, reg: 7.098e-01, hsize: 125)
# prediction accuracy - train: 0.496 | val: 0.481
# Progress: 111/360 (lr: 7.129e-04, lr_dec: 0.89, reg: 7.098e-01, hsize: 150)
# prediction accuracy - train: 0.497 | val: 0.471
# Progress: 112/360 (lr: 7.129e-04, lr_dec: 0.89, reg: 1.166e-01, hsize: 100)
# prediction accuracy - train: 0.500 | val: 0.484
# Progress: 113/360 (lr: 7.129e-04, lr_dec: 0.89, reg: 1.166e-01, hsize: 125)
# prediction accuracy - train: 0.500 | val: 0.482
# Progress: 114/360 (lr: 7.129e-04, lr_dec: 0.89, reg: 1.166e-01, hsize: 150)
# prediction accuracy - train: 0.502 | val: 0.484
# Progress: 115/360 (lr: 7.129e-04, lr_dec: 0.89, reg: 5.846e-02, hsize: 100)
# prediction accuracy - train: 0.497 | val: 0.470
# Progress: 116/360 (lr: 7.129e-04, lr_dec: 0.89, reg: 5.846e-02, hsize: 125)
# prediction accuracy - train: 0.503 | val: 0.462
# Progress: 117/360 (lr: 7.129e-04, lr_dec: 0.89, reg: 5.846e-02, hsize: 150)
# prediction accuracy - train: 0.506 | val: 0.476
# Progress: 118/360 (lr: 7.129e-04, lr_dec: 0.89, reg: 6.300e-02, hsize: 100)
# prediction accuracy - train: 0.498 | val: 0.482
# Progress: 119/360 (lr: 7.129e-04, lr_dec: 0.89, reg: 6.300e-02, hsize: 125)
# prediction accuracy - train: 0.505 | val: 0.480
# Progress: 120/360 (lr: 7.129e-04, lr_dec: 0.89, reg: 6.300e-02, hsize: 150)
# prediction accuracy - train: 0.505 | val: 0.482
# Progress: 121/360 (lr: 7.129e-04, lr_dec: 0.83, reg: 7.263e-01, hsize: 100)
# prediction accuracy - train: 0.479 | val: 0.464
# Progress: 122/360 (lr: 7.129e-04, lr_dec: 0.83, reg: 7.263e-01, hsize: 125)
# prediction accuracy - train: 0.483 | val: 0.469
# Progress: 123/360 (lr: 7.129e-04, lr_dec: 0.83, reg: 7.263e-01, hsize: 150)
# prediction accuracy - train: 0.481 | val: 0.469
# Progress: 124/360 (lr: 7.129e-04, lr_dec: 0.83, reg: 7.098e-01, hsize: 100)
# prediction accuracy - train: 0.479 | val: 0.466
# Progress: 125/360 (lr: 7.129e-04, lr_dec: 0.83, reg: 7.098e-01, hsize: 125)
# prediction accuracy - train: 0.479 | val: 0.460
# Progress: 126/360 (lr: 7.129e-04, lr_dec: 0.83, reg: 7.098e-01, hsize: 150)
# prediction accuracy - train: 0.482 | val: 0.464
# Progress: 127/360 (lr: 7.129e-04, lr_dec: 0.83, reg: 1.166e-01, hsize: 100)
# prediction accuracy - train: 0.486 | val: 0.464
# Progress: 128/360 (lr: 7.129e-04, lr_dec: 0.83, reg: 1.166e-01, hsize: 125)
# prediction accuracy - train: 0.484 | val: 0.469
# Progress: 129/360 (lr: 7.129e-04, lr_dec: 0.83, reg: 1.166e-01, hsize: 150)
# prediction accuracy - train: 0.490 | val: 0.477
# Progress: 130/360 (lr: 7.129e-04, lr_dec: 0.83, reg: 5.846e-02, hsize: 100)
# prediction accuracy - train: 0.486 | val: 0.481
# Progress: 131/360 (lr: 7.129e-04, lr_dec: 0.83, reg: 5.846e-02, hsize: 125)
# prediction accuracy - train: 0.489 | val: 0.463
# Progress: 132/360 (lr: 7.129e-04, lr_dec: 0.83, reg: 5.846e-02, hsize: 150)
# prediction accuracy - train: 0.493 | val: 0.481
# Progress: 133/360 (lr: 7.129e-04, lr_dec: 0.83, reg: 6.300e-02, hsize: 100)
# prediction accuracy - train: 0.486 | val: 0.474
# Progress: 134/360 (lr: 7.129e-04, lr_dec: 0.83, reg: 6.300e-02, hsize: 125)
# prediction accuracy - train: 0.487 | val: 0.466
# Progress: 135/360 (lr: 7.129e-04, lr_dec: 0.83, reg: 6.300e-02, hsize: 150)
# prediction accuracy - train: 0.490 | val: 0.467
# Progress: 136/360 (lr: 6.073e-04, lr_dec: 0.83, reg: 7.263e-01, hsize: 100)
# prediction accuracy - train: 0.465 | val: 0.459
# Progress: 137/360 (lr: 6.073e-04, lr_dec: 0.83, reg: 7.263e-01, hsize: 125)
# prediction accuracy - train: 0.469 | val: 0.467
# Progress: 138/360 (lr: 6.073e-04, lr_dec: 0.83, reg: 7.263e-01, hsize: 150)
# prediction accuracy - train: 0.468 | val: 0.457
# Progress: 139/360 (lr: 6.073e-04, lr_dec: 0.83, reg: 7.098e-01, hsize: 100)
# prediction accuracy - train: 0.463 | val: 0.461
# Progress: 140/360 (lr: 6.073e-04, lr_dec: 0.83, reg: 7.098e-01, hsize: 125)
# prediction accuracy - train: 0.467 | val: 0.467
# Progress: 141/360 (lr: 6.073e-04, lr_dec: 0.83, reg: 7.098e-01, hsize: 150)
# prediction accuracy - train: 0.468 | val: 0.466
# Progress: 142/360 (lr: 6.073e-04, lr_dec: 0.83, reg: 1.166e-01, hsize: 100)
# prediction accuracy - train: 0.474 | val: 0.464
# Progress: 143/360 (lr: 6.073e-04, lr_dec: 0.83, reg: 1.166e-01, hsize: 125)
# prediction accuracy - train: 0.476 | val: 0.466
# Progress: 144/360 (lr: 6.073e-04, lr_dec: 0.83, reg: 1.166e-01, hsize: 150)
# prediction accuracy - train: 0.476 | val: 0.467
# Progress: 145/360 (lr: 6.073e-04, lr_dec: 0.83, reg: 5.846e-02, hsize: 100)
# prediction accuracy - train: 0.471 | val: 0.451
# Progress: 146/360 (lr: 6.073e-04, lr_dec: 0.83, reg: 5.846e-02, hsize: 125)
# prediction accuracy - train: 0.477 | val: 0.470
# Progress: 147/360 (lr: 6.073e-04, lr_dec: 0.83, reg: 5.846e-02, hsize: 150)
# prediction accuracy - train: 0.477 | val: 0.464
# Progress: 148/360 (lr: 6.073e-04, lr_dec: 0.83, reg: 6.300e-02, hsize: 100)
# prediction accuracy - train: 0.473 | val: 0.458
# Progress: 149/360 (lr: 6.073e-04, lr_dec: 0.83, reg: 6.300e-02, hsize: 125)
# prediction accuracy - train: 0.472 | val: 0.466
# Progress: 150/360 (lr: 6.073e-04, lr_dec: 0.83, reg: 6.300e-02, hsize: 150)
# prediction accuracy - train: 0.473 | val: 0.471
# Progress: 151/360 (lr: 6.073e-04, lr_dec: 0.89, reg: 7.263e-01, hsize: 100)
# prediction accuracy - train: 0.481 | val: 0.466
# Progress: 152/360 (lr: 6.073e-04, lr_dec: 0.89, reg: 7.263e-01, hsize: 125)
# prediction accuracy - train: 0.483 | val: 0.466
# Progress: 153/360 (lr: 6.073e-04, lr_dec: 0.89, reg: 7.263e-01, hsize: 150)
# prediction accuracy - train: 0.480 | val: 0.469
# Progress: 154/360 (lr: 6.073e-04, lr_dec: 0.89, reg: 7.098e-01, hsize: 100)
# prediction accuracy - train: 0.482 | val: 0.474
# Progress: 155/360 (lr: 6.073e-04, lr_dec: 0.89, reg: 7.098e-01, hsize: 125)
# prediction accuracy - train: 0.480 | val: 0.466
# Progress: 156/360 (lr: 6.073e-04, lr_dec: 0.89, reg: 7.098e-01, hsize: 150)
# prediction accuracy - train: 0.480 | val: 0.479
# Progress: 157/360 (lr: 6.073e-04, lr_dec: 0.89, reg: 1.166e-01, hsize: 100)
# prediction accuracy - train: 0.488 | val: 0.475
# Progress: 158/360 (lr: 6.073e-04, lr_dec: 0.89, reg: 1.166e-01, hsize: 125)
# prediction accuracy - train: 0.487 | val: 0.466
# Progress: 159/360 (lr: 6.073e-04, lr_dec: 0.89, reg: 1.166e-01, hsize: 150)
# prediction accuracy - train: 0.489 | val: 0.479
# Progress: 160/360 (lr: 6.073e-04, lr_dec: 0.89, reg: 5.846e-02, hsize: 100)
# prediction accuracy - train: 0.490 | val: 0.473
# Progress: 161/360 (lr: 6.073e-04, lr_dec: 0.89, reg: 5.846e-02, hsize: 125)
# prediction accuracy - train: 0.491 | val: 0.472
# Progress: 162/360 (lr: 6.073e-04, lr_dec: 0.89, reg: 5.846e-02, hsize: 150)
# prediction accuracy - train: 0.495 | val: 0.467
# Progress: 163/360 (lr: 6.073e-04, lr_dec: 0.89, reg: 6.300e-02, hsize: 100)
# prediction accuracy - train: 0.486 | val: 0.475
# Progress: 164/360 (lr: 6.073e-04, lr_dec: 0.89, reg: 6.300e-02, hsize: 125)
# prediction accuracy - train: 0.488 | val: 0.469
# Progress: 165/360 (lr: 6.073e-04, lr_dec: 0.89, reg: 6.300e-02, hsize: 150)
# prediction accuracy - train: 0.491 | val: 0.455
# Progress: 166/360 (lr: 6.073e-04, lr_dec: 0.83, reg: 7.263e-01, hsize: 100)
# prediction accuracy - train: 0.464 | val: 0.469
# Progress: 167/360 (lr: 6.073e-04, lr_dec: 0.83, reg: 7.263e-01, hsize: 125)
# prediction accuracy - train: 0.466 | val: 0.458
# Progress: 168/360 (lr: 6.073e-04, lr_dec: 0.83, reg: 7.263e-01, hsize: 150)
# prediction accuracy - train: 0.470 | val: 0.476
# Progress: 169/360 (lr: 6.073e-04, lr_dec: 0.83, reg: 7.098e-01, hsize: 100)
# prediction accuracy - train: 0.467 | val: 0.457
# Progress: 170/360 (lr: 6.073e-04, lr_dec: 0.83, reg: 7.098e-01, hsize: 125)
# prediction accuracy - train: 0.467 | val: 0.459
# Progress: 171/360 (lr: 6.073e-04, lr_dec: 0.83, reg: 7.098e-01, hsize: 150)
# prediction accuracy - train: 0.467 | val: 0.454
# Progress: 172/360 (lr: 6.073e-04, lr_dec: 0.83, reg: 1.166e-01, hsize: 100)
# prediction accuracy - train: 0.469 | val: 0.458
# Progress: 173/360 (lr: 6.073e-04, lr_dec: 0.83, reg: 1.166e-01, hsize: 125)
# prediction accuracy - train: 0.472 | val: 0.471
# Progress: 174/360 (lr: 6.073e-04, lr_dec: 0.83, reg: 1.166e-01, hsize: 150)
# prediction accuracy - train: 0.473 | val: 0.474
# Progress: 175/360 (lr: 6.073e-04, lr_dec: 0.83, reg: 5.846e-02, hsize: 100)
# prediction accuracy - train: 0.474 | val: 0.458
# Progress: 176/360 (lr: 6.073e-04, lr_dec: 0.83, reg: 5.846e-02, hsize: 125)
# prediction accuracy - train: 0.473 | val: 0.458
# Progress: 177/360 (lr: 6.073e-04, lr_dec: 0.83, reg: 5.846e-02, hsize: 150)
# prediction accuracy - train: 0.474 | val: 0.463
# Progress: 178/360 (lr: 6.073e-04, lr_dec: 0.83, reg: 6.300e-02, hsize: 100)
# prediction accuracy - train: 0.472 | val: 0.449
# Progress: 179/360 (lr: 6.073e-04, lr_dec: 0.83, reg: 6.300e-02, hsize: 125)
# prediction accuracy - train: 0.474 | val: 0.468
# Progress: 180/360 (lr: 6.073e-04, lr_dec: 0.83, reg: 6.300e-02, hsize: 150)
# prediction accuracy - train: 0.476 | val: 0.475
# Progress: 181/360 (lr: 7.681e-04, lr_dec: 0.83, reg: 7.263e-01, hsize: 100)
# prediction accuracy - train: 0.483 | val: 0.460
# Progress: 182/360 (lr: 7.681e-04, lr_dec: 0.83, reg: 7.263e-01, hsize: 125)
# prediction accuracy - train: 0.487 | val: 0.455
# Progress: 183/360 (lr: 7.681e-04, lr_dec: 0.83, reg: 7.263e-01, hsize: 150)
# prediction accuracy - train: 0.488 | val: 0.480
# Progress: 184/360 (lr: 7.681e-04, lr_dec: 0.83, reg: 7.098e-01, hsize: 100)
# prediction accuracy - train: 0.484 | val: 0.457
# Progress: 185/360 (lr: 7.681e-04, lr_dec: 0.83, reg: 7.098e-01, hsize: 125)
# prediction accuracy - train: 0.484 | val: 0.480
# Progress: 186/360 (lr: 7.681e-04, lr_dec: 0.83, reg: 7.098e-01, hsize: 150)
# prediction accuracy - train: 0.488 | val: 0.475
# Progress: 187/360 (lr: 7.681e-04, lr_dec: 0.83, reg: 1.166e-01, hsize: 100)
# prediction accuracy - train: 0.493 | val: 0.466
# Progress: 188/360 (lr: 7.681e-04, lr_dec: 0.83, reg: 1.166e-01, hsize: 125)
# prediction accuracy - train: 0.492 | val: 0.466
# Progress: 189/360 (lr: 7.681e-04, lr_dec: 0.83, reg: 1.166e-01, hsize: 150)
# prediction accuracy - train: 0.498 | val: 0.480
# Progress: 190/360 (lr: 7.681e-04, lr_dec: 0.83, reg: 5.846e-02, hsize: 100)
# prediction accuracy - train: 0.493 | val: 0.471
# Progress: 191/360 (lr: 7.681e-04, lr_dec: 0.83, reg: 5.846e-02, hsize: 125)
# prediction accuracy - train: 0.495 | val: 0.464
# Progress: 192/360 (lr: 7.681e-04, lr_dec: 0.83, reg: 5.846e-02, hsize: 150)
# prediction accuracy - train: 0.496 | val: 0.471
# Progress: 193/360 (lr: 7.681e-04, lr_dec: 0.83, reg: 6.300e-02, hsize: 100)
# prediction accuracy - train: 0.493 | val: 0.477
# Progress: 194/360 (lr: 7.681e-04, lr_dec: 0.83, reg: 6.300e-02, hsize: 125)
# prediction accuracy - train: 0.495 | val: 0.483
# Progress: 195/360 (lr: 7.681e-04, lr_dec: 0.83, reg: 6.300e-02, hsize: 150)
# prediction accuracy - train: 0.496 | val: 0.467
# Progress: 196/360 (lr: 7.681e-04, lr_dec: 0.89, reg: 7.263e-01, hsize: 100)
# prediction accuracy - train: 0.497 | val: 0.475
# Progress: 197/360 (lr: 7.681e-04, lr_dec: 0.89, reg: 7.263e-01, hsize: 125)
# prediction accuracy - train: 0.494 | val: 0.479
# Progress: 198/360 (lr: 7.681e-04, lr_dec: 0.89, reg: 7.263e-01, hsize: 150)
# prediction accuracy - train: 0.495 | val: 0.468
# Progress: 199/360 (lr: 7.681e-04, lr_dec: 0.89, reg: 7.098e-01, hsize: 100)
# prediction accuracy - train: 0.495 | val: 0.478
# Progress: 200/360 (lr: 7.681e-04, lr_dec: 0.89, reg: 7.098e-01, hsize: 125)
# prediction accuracy - train: 0.498 | val: 0.497
# Progress: 201/360 (lr: 7.681e-04, lr_dec: 0.89, reg: 7.098e-01, hsize: 150)
# prediction accuracy - train: 0.500 | val: 0.463
# Progress: 202/360 (lr: 7.681e-04, lr_dec: 0.89, reg: 1.166e-01, hsize: 100)
# prediction accuracy - train: 0.508 | val: 0.492
# Progress: 203/360 (lr: 7.681e-04, lr_dec: 0.89, reg: 1.166e-01, hsize: 125)
# prediction accuracy - train: 0.508 | val: 0.472
# Progress: 204/360 (lr: 7.681e-04, lr_dec: 0.89, reg: 1.166e-01, hsize: 150)
# prediction accuracy - train: 0.507 | val: 0.486
# Progress: 205/360 (lr: 7.681e-04, lr_dec: 0.89, reg: 5.846e-02, hsize: 100)
# prediction accuracy - train: 0.505 | val: 0.487
# Progress: 206/360 (lr: 7.681e-04, lr_dec: 0.89, reg: 5.846e-02, hsize: 125)
# prediction accuracy - train: 0.509 | val: 0.482
# Progress: 207/360 (lr: 7.681e-04, lr_dec: 0.89, reg: 5.846e-02, hsize: 150)
# prediction accuracy - train: 0.514 | val: 0.484
# Progress: 208/360 (lr: 7.681e-04, lr_dec: 0.89, reg: 6.300e-02, hsize: 100)
# prediction accuracy - train: 0.506 | val: 0.479
# Progress: 209/360 (lr: 7.681e-04, lr_dec: 0.89, reg: 6.300e-02, hsize: 125)
# prediction accuracy - train: 0.507 | val: 0.462
# Progress: 210/360 (lr: 7.681e-04, lr_dec: 0.89, reg: 6.300e-02, hsize: 150)
# prediction accuracy - train: 0.504 | val: 0.485
# Progress: 211/360 (lr: 7.681e-04, lr_dec: 0.83, reg: 7.263e-01, hsize: 100)
# prediction accuracy - train: 0.484 | val: 0.462
# Progress: 212/360 (lr: 7.681e-04, lr_dec: 0.83, reg: 7.263e-01, hsize: 125)
# prediction accuracy - train: 0.485 | val: 0.470
# Progress: 213/360 (lr: 7.681e-04, lr_dec: 0.83, reg: 7.263e-01, hsize: 150)
# prediction accuracy - train: 0.488 | val: 0.489
# Progress: 214/360 (lr: 7.681e-04, lr_dec: 0.83, reg: 7.098e-01, hsize: 100)
# prediction accuracy - train: 0.485 | val: 0.461
# Progress: 215/360 (lr: 7.681e-04, lr_dec: 0.83, reg: 7.098e-01, hsize: 125)
# prediction accuracy - train: 0.489 | val: 0.465
# Progress: 216/360 (lr: 7.681e-04, lr_dec: 0.83, reg: 7.098e-01, hsize: 150)
# prediction accuracy - train: 0.486 | val: 0.463
# Progress: 217/360 (lr: 7.681e-04, lr_dec: 0.83, reg: 1.166e-01, hsize: 100)
# prediction accuracy - train: 0.489 | val: 0.467
# Progress: 218/360 (lr: 7.681e-04, lr_dec: 0.83, reg: 1.166e-01, hsize: 125)
# prediction accuracy - train: 0.494 | val: 0.481
# Progress: 219/360 (lr: 7.681e-04, lr_dec: 0.83, reg: 1.166e-01, hsize: 150)
# prediction accuracy - train: 0.497 | val: 0.487
# Progress: 220/360 (lr: 7.681e-04, lr_dec: 0.83, reg: 5.846e-02, hsize: 100)
# prediction accuracy - train: 0.491 | val: 0.477
# Progress: 221/360 (lr: 7.681e-04, lr_dec: 0.83, reg: 5.846e-02, hsize: 125)
# prediction accuracy - train: 0.494 | val: 0.477
# Progress: 222/360 (lr: 7.681e-04, lr_dec: 0.83, reg: 5.846e-02, hsize: 150)
# prediction accuracy - train: 0.494 | val: 0.471
# Progress: 223/360 (lr: 7.681e-04, lr_dec: 0.83, reg: 6.300e-02, hsize: 100)
# prediction accuracy - train: 0.491 | val: 0.481
# Progress: 224/360 (lr: 7.681e-04, lr_dec: 0.83, reg: 6.300e-02, hsize: 125)
# prediction accuracy - train: 0.496 | val: 0.472
# Progress: 225/360 (lr: 7.681e-04, lr_dec: 0.83, reg: 6.300e-02, hsize: 150)
# prediction accuracy - train: 0.497 | val: 0.475
# Progress: 226/360 (lr: 1.045e-03, lr_dec: 0.83, reg: 7.263e-01, hsize: 100)
# prediction accuracy - train: 0.498 | val: 0.468
# Progress: 227/360 (lr: 1.045e-03, lr_dec: 0.83, reg: 7.263e-01, hsize: 125)
# prediction accuracy - train: 0.511 | val: 0.476
# Progress: 228/360 (lr: 1.045e-03, lr_dec: 0.83, reg: 7.263e-01, hsize: 150)
# prediction accuracy - train: 0.512 | val: 0.484
# Progress: 229/360 (lr: 1.045e-03, lr_dec: 0.83, reg: 7.098e-01, hsize: 100)
# prediction accuracy - train: 0.505 | val: 0.472
# Progress: 230/360 (lr: 1.045e-03, lr_dec: 0.83, reg: 7.098e-01, hsize: 125)
# prediction accuracy - train: 0.509 | val: 0.487
# Progress: 231/360 (lr: 1.045e-03, lr_dec: 0.83, reg: 7.098e-01, hsize: 150)
# prediction accuracy - train: 0.510 | val: 0.489
# Progress: 232/360 (lr: 1.045e-03, lr_dec: 0.83, reg: 1.166e-01, hsize: 100)
# prediction accuracy - train: 0.514 | val: 0.486
# Progress: 233/360 (lr: 1.045e-03, lr_dec: 0.83, reg: 1.166e-01, hsize: 125)
# prediction accuracy - train: 0.517 | val: 0.500
# Progress: 234/360 (lr: 1.045e-03, lr_dec: 0.83, reg: 1.166e-01, hsize: 150)
# prediction accuracy - train: 0.519 | val: 0.475
# Progress: 235/360 (lr: 1.045e-03, lr_dec: 0.83, reg: 5.846e-02, hsize: 100)
# prediction accuracy - train: 0.519 | val: 0.500
# Progress: 236/360 (lr: 1.045e-03, lr_dec: 0.83, reg: 5.846e-02, hsize: 125)
# prediction accuracy - train: 0.520 | val: 0.503
# Progress: 237/360 (lr: 1.045e-03, lr_dec: 0.83, reg: 5.846e-02, hsize: 150)
# prediction accuracy - train: 0.521 | val: 0.491
# Progress: 238/360 (lr: 1.045e-03, lr_dec: 0.83, reg: 6.300e-02, hsize: 100)
# prediction accuracy - train: 0.517 | val: 0.493
# Progress: 239/360 (lr: 1.045e-03, lr_dec: 0.83, reg: 6.300e-02, hsize: 125)
# prediction accuracy - train: 0.522 | val: 0.486
# Progress: 240/360 (lr: 1.045e-03, lr_dec: 0.83, reg: 6.300e-02, hsize: 150)
# prediction accuracy - train: 0.522 | val: 0.491
# Progress: 241/360 (lr: 1.045e-03, lr_dec: 0.89, reg: 7.263e-01, hsize: 100)
# prediction accuracy - train: 0.511 | val: 0.492
# Progress: 242/360 (lr: 1.045e-03, lr_dec: 0.89, reg: 7.263e-01, hsize: 125)
# prediction accuracy - train: 0.517 | val: 0.494
# Progress: 243/360 (lr: 1.045e-03, lr_dec: 0.89, reg: 7.263e-01, hsize: 150)
# prediction accuracy - train: 0.516 | val: 0.497
# Progress: 244/360 (lr: 1.045e-03, lr_dec: 0.89, reg: 7.098e-01, hsize: 100)
# prediction accuracy - train: 0.513 | val: 0.494
# Progress: 245/360 (lr: 1.045e-03, lr_dec: 0.89, reg: 7.098e-01, hsize: 125)
# prediction accuracy - train: 0.517 | val: 0.500
# Progress: 246/360 (lr: 1.045e-03, lr_dec: 0.89, reg: 7.098e-01, hsize: 150)
# prediction accuracy - train: 0.516 | val: 0.493
# Progress: 247/360 (lr: 1.045e-03, lr_dec: 0.89, reg: 1.166e-01, hsize: 100)
# prediction accuracy - train: 0.528 | val: 0.504
# Progress: 248/360 (lr: 1.045e-03, lr_dec: 0.89, reg: 1.166e-01, hsize: 125)
# prediction accuracy - train: 0.523 | val: 0.493
# Progress: 249/360 (lr: 1.045e-03, lr_dec: 0.89, reg: 1.166e-01, hsize: 150)
# prediction accuracy - train: 0.537 | val: 0.514
# Progress: 250/360 (lr: 1.045e-03, lr_dec: 0.89, reg: 5.846e-02, hsize: 100)
# prediction accuracy - train: 0.531 | val: 0.506
# Progress: 251/360 (lr: 1.045e-03, lr_dec: 0.89, reg: 5.846e-02, hsize: 125)
# prediction accuracy - train: 0.531 | val: 0.486
# Progress: 252/360 (lr: 1.045e-03, lr_dec: 0.89, reg: 5.846e-02, hsize: 150)
# prediction accuracy - train: 0.535 | val: 0.504
# Progress: 253/360 (lr: 1.045e-03, lr_dec: 0.89, reg: 6.300e-02, hsize: 100)
# prediction accuracy - train: 0.525 | val: 0.510
# Progress: 254/360 (lr: 1.045e-03, lr_dec: 0.89, reg: 6.300e-02, hsize: 125)
# prediction accuracy - train: 0.527 | val: 0.491
# Progress: 255/360 (lr: 1.045e-03, lr_dec: 0.89, reg: 6.300e-02, hsize: 150)
# prediction accuracy - train: 0.530 | val: 0.496
# Progress: 256/360 (lr: 1.045e-03, lr_dec: 0.83, reg: 7.263e-01, hsize: 100)
# prediction accuracy - train: 0.502 | val: 0.479
# Progress: 257/360 (lr: 1.045e-03, lr_dec: 0.83, reg: 7.263e-01, hsize: 125)
# prediction accuracy - train: 0.507 | val: 0.497
# Progress: 258/360 (lr: 1.045e-03, lr_dec: 0.83, reg: 7.263e-01, hsize: 150)
# prediction accuracy - train: 0.508 | val: 0.475
# Progress: 259/360 (lr: 1.045e-03, lr_dec: 0.83, reg: 7.098e-01, hsize: 100)
# prediction accuracy - train: 0.505 | val: 0.483
# Progress: 260/360 (lr: 1.045e-03, lr_dec: 0.83, reg: 7.098e-01, hsize: 125)
# prediction accuracy - train: 0.509 | val: 0.480
# Progress: 261/360 (lr: 1.045e-03, lr_dec: 0.83, reg: 7.098e-01, hsize: 150)
# prediction accuracy - train: 0.510 | val: 0.482
# Progress: 262/360 (lr: 1.045e-03, lr_dec: 0.83, reg: 1.166e-01, hsize: 100)
# prediction accuracy - train: 0.513 | val: 0.482
# Progress: 263/360 (lr: 1.045e-03, lr_dec: 0.83, reg: 1.166e-01, hsize: 125)
# prediction accuracy - train: 0.521 | val: 0.489
# Progress: 264/360 (lr: 1.045e-03, lr_dec: 0.83, reg: 1.166e-01, hsize: 150)
# prediction accuracy - train: 0.521 | val: 0.498
# Progress: 265/360 (lr: 1.045e-03, lr_dec: 0.83, reg: 5.846e-02, hsize: 100)
# prediction accuracy - train: 0.516 | val: 0.483
# Progress: 266/360 (lr: 1.045e-03, lr_dec: 0.83, reg: 5.846e-02, hsize: 125)
# prediction accuracy - train: 0.521 | val: 0.489
# Progress: 267/360 (lr: 1.045e-03, lr_dec: 0.83, reg: 5.846e-02, hsize: 150)
# prediction accuracy - train: 0.520 | val: 0.492
# Progress: 268/360 (lr: 1.045e-03, lr_dec: 0.83, reg: 6.300e-02, hsize: 100)
# prediction accuracy - train: 0.516 | val: 0.483
# Progress: 269/360 (lr: 1.045e-03, lr_dec: 0.83, reg: 6.300e-02, hsize: 125)
# prediction accuracy - train: 0.517 | val: 0.488
# Progress: 270/360 (lr: 1.045e-03, lr_dec: 0.83, reg: 6.300e-02, hsize: 150)
# prediction accuracy - train: 0.522 | val: 0.496
# Progress: 271/360 (lr: 6.379e-04, lr_dec: 0.83, reg: 7.263e-01, hsize: 100)
# prediction accuracy - train: 0.468 | val: 0.469
# Progress: 272/360 (lr: 6.379e-04, lr_dec: 0.83, reg: 7.263e-01, hsize: 125)
# prediction accuracy - train: 0.470 | val: 0.457
# Progress: 273/360 (lr: 6.379e-04, lr_dec: 0.83, reg: 7.263e-01, hsize: 150)
# prediction accuracy - train: 0.474 | val: 0.465
# Progress: 274/360 (lr: 6.379e-04, lr_dec: 0.83, reg: 7.098e-01, hsize: 100)
# prediction accuracy - train: 0.468 | val: 0.467
# Progress: 275/360 (lr: 6.379e-04, lr_dec: 0.83, reg: 7.098e-01, hsize: 125)
# prediction accuracy - train: 0.472 | val: 0.466
# Progress: 276/360 (lr: 6.379e-04, lr_dec: 0.83, reg: 7.098e-01, hsize: 150)
# prediction accuracy - train: 0.473 | val: 0.471
# Progress: 277/360 (lr: 6.379e-04, lr_dec: 0.83, reg: 1.166e-01, hsize: 100)
# prediction accuracy - train: 0.475 | val: 0.460
# Progress: 278/360 (lr: 6.379e-04, lr_dec: 0.83, reg: 1.166e-01, hsize: 125)
# prediction accuracy - train: 0.480 | val: 0.472
# Progress: 279/360 (lr: 6.379e-04, lr_dec: 0.83, reg: 1.166e-01, hsize: 150)
# prediction accuracy - train: 0.482 | val: 0.462
# Progress: 280/360 (lr: 6.379e-04, lr_dec: 0.83, reg: 5.846e-02, hsize: 100)
# prediction accuracy - train: 0.479 | val: 0.455
# Progress: 281/360 (lr: 6.379e-04, lr_dec: 0.83, reg: 5.846e-02, hsize: 125)
# prediction accuracy - train: 0.479 | val: 0.462
# Progress: 282/360 (lr: 6.379e-04, lr_dec: 0.83, reg: 5.846e-02, hsize: 150)
# prediction accuracy - train: 0.481 | val: 0.469
# Progress: 283/360 (lr: 6.379e-04, lr_dec: 0.83, reg: 6.300e-02, hsize: 100)
# prediction accuracy - train: 0.474 | val: 0.456
# Progress: 284/360 (lr: 6.379e-04, lr_dec: 0.83, reg: 6.300e-02, hsize: 125)
# prediction accuracy - train: 0.477 | val: 0.451
# Progress: 285/360 (lr: 6.379e-04, lr_dec: 0.83, reg: 6.300e-02, hsize: 150)
# prediction accuracy - train: 0.484 | val: 0.472
# Progress: 286/360 (lr: 6.379e-04, lr_dec: 0.89, reg: 7.263e-01, hsize: 100)
# prediction accuracy - train: 0.481 | val: 0.466
# Progress: 287/360 (lr: 6.379e-04, lr_dec: 0.89, reg: 7.263e-01, hsize: 125)
# prediction accuracy - train: 0.482 | val: 0.452
# Progress: 288/360 (lr: 6.379e-04, lr_dec: 0.89, reg: 7.263e-01, hsize: 150)
# prediction accuracy - train: 0.486 | val: 0.470
# Progress: 289/360 (lr: 6.379e-04, lr_dec: 0.89, reg: 7.098e-01, hsize: 100)
# prediction accuracy - train: 0.480 | val: 0.460
# Progress: 290/360 (lr: 6.379e-04, lr_dec: 0.89, reg: 7.098e-01, hsize: 125)
# prediction accuracy - train: 0.482 | val: 0.469
# Progress: 291/360 (lr: 6.379e-04, lr_dec: 0.89, reg: 7.098e-01, hsize: 150)
# prediction accuracy - train: 0.481 | val: 0.472
# Progress: 292/360 (lr: 6.379e-04, lr_dec: 0.89, reg: 1.166e-01, hsize: 100)
# prediction accuracy - train: 0.490 | val: 0.472
# Progress: 293/360 (lr: 6.379e-04, lr_dec: 0.89, reg: 1.166e-01, hsize: 125)
# prediction accuracy - train: 0.490 | val: 0.474
# Progress: 294/360 (lr: 6.379e-04, lr_dec: 0.89, reg: 1.166e-01, hsize: 150)
# prediction accuracy - train: 0.496 | val: 0.479
# Progress: 295/360 (lr: 6.379e-04, lr_dec: 0.89, reg: 5.846e-02, hsize: 100)
# prediction accuracy - train: 0.488 | val: 0.476
# Progress: 296/360 (lr: 6.379e-04, lr_dec: 0.89, reg: 5.846e-02, hsize: 125)
# prediction accuracy - train: 0.496 | val: 0.473
# Progress: 297/360 (lr: 6.379e-04, lr_dec: 0.89, reg: 5.846e-02, hsize: 150)
# prediction accuracy - train: 0.495 | val: 0.484
# Progress: 298/360 (lr: 6.379e-04, lr_dec: 0.89, reg: 6.300e-02, hsize: 100)
# prediction accuracy - train: 0.487 | val: 0.465
# Progress: 299/360 (lr: 6.379e-04, lr_dec: 0.89, reg: 6.300e-02, hsize: 125)
# prediction accuracy - train: 0.494 | val: 0.475
# Progress: 300/360 (lr: 6.379e-04, lr_dec: 0.89, reg: 6.300e-02, hsize: 150)
# prediction accuracy - train: 0.495 | val: 0.472
# Progress: 301/360 (lr: 6.379e-04, lr_dec: 0.83, reg: 7.263e-01, hsize: 100)
# prediction accuracy - train: 0.468 | val: 0.463
# Progress: 302/360 (lr: 6.379e-04, lr_dec: 0.83, reg: 7.263e-01, hsize: 125)
# prediction accuracy - train: 0.471 | val: 0.461
# Progress: 303/360 (lr: 6.379e-04, lr_dec: 0.83, reg: 7.263e-01, hsize: 150)
# prediction accuracy - train: 0.471 | val: 0.456
# Progress: 304/360 (lr: 6.379e-04, lr_dec: 0.83, reg: 7.098e-01, hsize: 100)
# prediction accuracy - train: 0.469 | val: 0.462
# Progress: 305/360 (lr: 6.379e-04, lr_dec: 0.83, reg: 7.098e-01, hsize: 125)
# prediction accuracy - train: 0.471 | val: 0.451
# Progress: 306/360 (lr: 6.379e-04, lr_dec: 0.83, reg: 7.098e-01, hsize: 150)
# prediction accuracy - train: 0.476 | val: 0.467
# Progress: 307/360 (lr: 6.379e-04, lr_dec: 0.83, reg: 1.166e-01, hsize: 100)
# prediction accuracy - train: 0.477 | val: 0.462
# Progress: 308/360 (lr: 6.379e-04, lr_dec: 0.83, reg: 1.166e-01, hsize: 125)
# prediction accuracy - train: 0.479 | val: 0.470
# Progress: 309/360 (lr: 6.379e-04, lr_dec: 0.83, reg: 1.166e-01, hsize: 150)
# prediction accuracy - train: 0.482 | val: 0.466
# Progress: 310/360 (lr: 6.379e-04, lr_dec: 0.83, reg: 5.846e-02, hsize: 100)
# prediction accuracy - train: 0.476 | val: 0.471
# Progress: 311/360 (lr: 6.379e-04, lr_dec: 0.83, reg: 5.846e-02, hsize: 125)
# prediction accuracy - train: 0.479 | val: 0.463
# Progress: 312/360 (lr: 6.379e-04, lr_dec: 0.83, reg: 5.846e-02, hsize: 150)
# prediction accuracy - train: 0.479 | val: 0.467
# Progress: 313/360 (lr: 6.379e-04, lr_dec: 0.83, reg: 6.300e-02, hsize: 100)
# prediction accuracy - train: 0.475 | val: 0.458
# Progress: 314/360 (lr: 6.379e-04, lr_dec: 0.83, reg: 6.300e-02, hsize: 125)
# prediction accuracy - train: 0.481 | val: 0.457
# Progress: 315/360 (lr: 6.379e-04, lr_dec: 0.83, reg: 6.300e-02, hsize: 150)
# prediction accuracy - train: 0.480 | val: 0.472
# Progress: 316/360 (lr: 1.035e-03, lr_dec: 0.83, reg: 7.263e-01, hsize: 100)
# prediction accuracy - train: 0.502 | val: 0.473
# Progress: 317/360 (lr: 1.035e-03, lr_dec: 0.83, reg: 7.263e-01, hsize: 125)
# prediction accuracy - train: 0.508 | val: 0.477
# Progress: 318/360 (lr: 1.035e-03, lr_dec: 0.83, reg: 7.263e-01, hsize: 150)
# prediction accuracy - train: 0.507 | val: 0.490
# Progress: 319/360 (lr: 1.035e-03, lr_dec: 0.83, reg: 7.098e-01, hsize: 100)
# prediction accuracy - train: 0.507 | val: 0.489
# Progress: 320/360 (lr: 1.035e-03, lr_dec: 0.83, reg: 7.098e-01, hsize: 125)
# prediction accuracy - train: 0.506 | val: 0.482
# Progress: 321/360 (lr: 1.035e-03, lr_dec: 0.83, reg: 7.098e-01, hsize: 150)
# prediction accuracy - train: 0.511 | val: 0.492
# Progress: 322/360 (lr: 1.035e-03, lr_dec: 0.83, reg: 1.166e-01, hsize: 100)
# prediction accuracy - train: 0.512 | val: 0.488
# Progress: 323/360 (lr: 1.035e-03, lr_dec: 0.83, reg: 1.166e-01, hsize: 125)
# prediction accuracy - train: 0.518 | val: 0.501
# Progress: 324/360 (lr: 1.035e-03, lr_dec: 0.83, reg: 1.166e-01, hsize: 150)
# prediction accuracy - train: 0.521 | val: 0.498
# Progress: 325/360 (lr: 1.035e-03, lr_dec: 0.83, reg: 5.846e-02, hsize: 100)
# prediction accuracy - train: 0.514 | val: 0.483
# Progress: 326/360 (lr: 1.035e-03, lr_dec: 0.83, reg: 5.846e-02, hsize: 125)
# prediction accuracy - train: 0.522 | val: 0.491
# Progress: 327/360 (lr: 1.035e-03, lr_dec: 0.83, reg: 5.846e-02, hsize: 150)
# prediction accuracy - train: 0.523 | val: 0.489
# Progress: 328/360 (lr: 1.035e-03, lr_dec: 0.83, reg: 6.300e-02, hsize: 100)
# prediction accuracy - train: 0.512 | val: 0.493
# Progress: 329/360 (lr: 1.035e-03, lr_dec: 0.83, reg: 6.300e-02, hsize: 125)
# prediction accuracy - train: 0.521 | val: 0.494
# Progress: 330/360 (lr: 1.035e-03, lr_dec: 0.83, reg: 6.300e-02, hsize: 150)
# prediction accuracy - train: 0.523 | val: 0.503
# Progress: 331/360 (lr: 1.035e-03, lr_dec: 0.89, reg: 7.263e-01, hsize: 100)
# prediction accuracy - train: 0.512 | val: 0.483
# Progress: 332/360 (lr: 1.035e-03, lr_dec: 0.89, reg: 7.263e-01, hsize: 125)
# prediction accuracy - train: 0.510 | val: 0.492
# Progress: 333/360 (lr: 1.035e-03, lr_dec: 0.89, reg: 7.263e-01, hsize: 150)
# prediction accuracy - train: 0.518 | val: 0.488
# Progress: 334/360 (lr: 1.035e-03, lr_dec: 0.89, reg: 7.098e-01, hsize: 100)
# prediction accuracy - train: 0.512 | val: 0.482
# Progress: 335/360 (lr: 1.035e-03, lr_dec: 0.89, reg: 7.098e-01, hsize: 125)
# prediction accuracy - train: 0.518 | val: 0.492
# Progress: 336/360 (lr: 1.035e-03, lr_dec: 0.89, reg: 7.098e-01, hsize: 150)
# prediction accuracy - train: 0.522 | val: 0.498
# Progress: 337/360 (lr: 1.035e-03, lr_dec: 0.89, reg: 1.166e-01, hsize: 100)
# prediction accuracy - train: 0.523 | val: 0.486
# Progress: 338/360 (lr: 1.035e-03, lr_dec: 0.89, reg: 1.166e-01, hsize: 125)
# prediction accuracy - train: 0.531 | val: 0.501
# Progress: 339/360 (lr: 1.035e-03, lr_dec: 0.89, reg: 1.166e-01, hsize: 150)
# prediction accuracy - train: 0.535 | val: 0.496
# Progress: 340/360 (lr: 1.035e-03, lr_dec: 0.89, reg: 5.846e-02, hsize: 100)
# prediction accuracy - train: 0.528 | val: 0.485
# Progress: 341/360 (lr: 1.035e-03, lr_dec: 0.89, reg: 5.846e-02, hsize: 125)
# prediction accuracy - train: 0.530 | val: 0.498
# Progress: 342/360 (lr: 1.035e-03, lr_dec: 0.89, reg: 5.846e-02, hsize: 150)
# prediction accuracy - train: 0.534 | val: 0.505
# Progress: 343/360 (lr: 1.035e-03, lr_dec: 0.89, reg: 6.300e-02, hsize: 100)
# prediction accuracy - train: 0.523 | val: 0.496
# Progress: 344/360 (lr: 1.035e-03, lr_dec: 0.89, reg: 6.300e-02, hsize: 125)
# prediction accuracy - train: 0.533 | val: 0.491
# Progress: 345/360 (lr: 1.035e-03, lr_dec: 0.89, reg: 6.300e-02, hsize: 150)
# prediction accuracy - train: 0.537 | val: 0.512
# Progress: 346/360 (lr: 1.035e-03, lr_dec: 0.83, reg: 7.263e-01, hsize: 100)
# prediction accuracy - train: 0.502 | val: 0.472
# Progress: 347/360 (lr: 1.035e-03, lr_dec: 0.83, reg: 7.263e-01, hsize: 125)
# prediction accuracy - train: 0.510 | val: 0.489
# Progress: 348/360 (lr: 1.035e-03, lr_dec: 0.83, reg: 7.263e-01, hsize: 150)
# prediction accuracy - train: 0.507 | val: 0.483
# Progress: 349/360 (lr: 1.035e-03, lr_dec: 0.83, reg: 7.098e-01, hsize: 100)
# prediction accuracy - train: 0.503 | val: 0.479
# Progress: 350/360 (lr: 1.035e-03, lr_dec: 0.83, reg: 7.098e-01, hsize: 125)
# prediction accuracy - train: 0.506 | val: 0.493
# Progress: 351/360 (lr: 1.035e-03, lr_dec: 0.83, reg: 7.098e-01, hsize: 150)
# prediction accuracy - train: 0.508 | val: 0.482
# Progress: 352/360 (lr: 1.035e-03, lr_dec: 0.83, reg: 1.166e-01, hsize: 100)
# prediction accuracy - train: 0.517 | val: 0.493
# Progress: 353/360 (lr: 1.035e-03, lr_dec: 0.83, reg: 1.166e-01, hsize: 125)
# prediction accuracy - train: 0.518 | val: 0.479
# Progress: 354/360 (lr: 1.035e-03, lr_dec: 0.83, reg: 1.166e-01, hsize: 150)
# prediction accuracy - train: 0.520 | val: 0.493
# Progress: 355/360 (lr: 1.035e-03, lr_dec: 0.83, reg: 5.846e-02, hsize: 100)
# prediction accuracy - train: 0.514 | val: 0.489
# Progress: 356/360 (lr: 1.035e-03, lr_dec: 0.83, reg: 5.846e-02, hsize: 125)
# prediction accuracy - train: 0.519 | val: 0.481
# Progress: 357/360 (lr: 1.035e-03, lr_dec: 0.83, reg: 5.846e-02, hsize: 150)
# prediction accuracy - train: 0.520 | val: 0.490
# Progress: 358/360 (lr: 1.035e-03, lr_dec: 0.83, reg: 6.300e-02, hsize: 100)
# prediction accuracy - train: 0.518 | val: 0.486
# Progress: 359/360 (lr: 1.035e-03, lr_dec: 0.83, reg: 6.300e-02, hsize: 125)
# prediction accuracy - train: 0.521 | val: 0.485
# Progress: 360/360 (lr: 1.035e-03, lr_dec: 0.83, reg: 6.300e-02, hsize: 150)
# prediction accuracy - train: 0.521 | val: 0.486
# Done training.
#
# Best validation accuracy: 0.528
# Hyperparameters: {'lr': 0.0014087526129716171, 'lr_dec': 0.88850807590803327, 'reg': 0.063002302953668585, 'hsize': 125}

# %%
# visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 48%.
#
# **We will give you extra bonus point for every 1% of accuracy above 52%.**

# %%
test_acc = (best_net.predict(X_test) == y_test).mean()
print('Test accuracy: ', test_acc)
# Out:
# Test accuracy:  0.511

# %%
from pathlib import Path

file = Path("C:/Users/zadnik/NN_result.txt")

with open(file, 'w') as wf:
    wf.write("Test accuracy: {}\n".format(test_acc))
    wf.write("Best validation accuracy: {}\n".format(best_val[0]))
    wf.write("Hyperparameters: {}\n".format(best_val[1]))
    wf.write("\nResults:\n{}".format(results))
